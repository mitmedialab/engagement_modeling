# %% [markdown]
# # Modlling for engagement
#
# now we have the features and the lables, we are ready for modelling
# - Classification vs regression
# - 9 vs 5 vs 3 scales lables
# - 2.5 vs 5 s window (as is features, average featuers and concatenate features)
# - Two-stream Fusion on RGB + Flow
#
# This should be done over:
# - different network artchictures
# - cross different familys cross-validation
#
# Later on:
# - Handcrafted features

# %% [markdown]
# ### imports and vars

# %%
import sys
import numpy as np
import os
import pandas as pd
import itertools
import pickle
import warnings
warnings.filterwarnings('ignore')

import logging
logger = logging.getLogger()
logger.setLevel(logging.CRITICAL)

import logging, sys
logging.disable(sys.maxsize)

import smote_variants as sv
from collections import Counter
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from operator import itemgetter

lables_path = './labels/'
features_path = './features/'
results_path = './modelling_results/'

# %% [markdown]
# ### Keras modeling class

# %% [markdown]
# ### help functions

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten

import ConfigSpace as CS
import ConfigSpace.hyperparameters as CSH

from hpbandster.core.worker import Worker
from hpbandster.optimizers import BOHB as BOHB
import hpbandster.core.nameserver as hpns
import hpbandster.core.result as hpres

import tensorflow_addons as tfa

import logging
logging.basicConfig(level=logging.ERROR)

class KerasWorker(Worker):
    def __init__(self, input_shape, output_shape, problemType,
                 x_train, y_train, x_validation, y_validation,
                 x_test, y_test, shared_directory, **kwargs):
            super().__init__(**kwargs)
            self.input_shape = (input_shape, )
            self.num_classes = output_shape
            self.batch_size = 64
            self.save_dic = shared_directory
            
            self.problemType = problemType

            self.x_train, self.y_train = x_train, y_train
            self.x_validation, self.y_validation = x_validation, y_validation
            self.x_test, self.y_test = x_test, y_test

    def compute(self, config, budget, working_directory, *args, **kwargs):
            model = Sequential()
            model.add(Dense(units=config['start_neurons_units'],
                            # activation=config['start_neurons_activation'],
                            activation='relu',
                            input_shape=self.input_shape))


            if config['num_dense_layers'] > 1:
                model.add(Dense(units=config['dense1_units'],
                                # activation=config['dense1_activation'],
                                activation='relu',
                                input_shape=self.input_shape))
                model.add(Dropout(config['dropout1_rate']))

            if config['num_dense_layers'] > 2:
                model.add(Dense(units=config['dense2_units'],
                                # activation=config['dense2_activation'],
                                activation='relu',
                                input_shape=self.input_shape))
                model.add(Dropout(config['dropout2_rate']))

            model.add(Dense(self.num_classes, activation='softmax'))


            if config['optimizer'] == 'Adam':
                    optimizer = tf.keras.optimizers.Adam(lr=config['lr'])
            else:
                    optimizer = tf.keras.optimizers.SGD(lr=config['lr'], momentum=config['sgd_momentum'])
            
            loss_fn = tf.keras.losses.CategoricalCrossentropy(from_logits=True)
            
            METRICS = [
                  tf.keras.metrics.TruePositives(name='tp'),
                  tf.keras.metrics.FalsePositives(name='fp'),
                  tf.keras.metrics.TrueNegatives(name='tn'),
                  tf.keras.metrics.FalseNegatives(name='fn'),
                  tf.keras.metrics.BinaryAccuracy(name='accuracy'),
                  tf.keras.metrics.Precision(name='precision'),
                  tf.keras.metrics.Recall(name='recall'),
                  tf.keras.metrics.AUC(name='auc'),
                  tf.keras.metrics.BinaryCrossentropy(name='BinaryCrossentropy'),
                  tfa.metrics.MatthewsCorrelationCoefficient(num_classes=self.num_classes)
            ]

            #METRICS.append(tfa.metrics.MatthewsCorrelationCoefficient(num_classes=self.num_classes))
            
            the_columns = ['thisloss','tp','fp','tn','fn','acc','prec','rec','auc','BC','MCC']
            
            model.compile(
                loss=loss_fn,
                optimizer=optimizer,
                metrics=METRICS
            )

            # model.summary()
            _history = model.fit(self.x_train, self.y_train,
                              batch_size=self.batch_size,
                              epochs=int(budget),
                              verbose=0,
                              validation_data=(self.x_validation, self.y_validation))

            val_acc_per_epoch = _history.history['val_accuracy']
            best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1

            model.fit(self.x_train, self.y_train,
                              batch_size=self.batch_size,
                              epochs=best_epoch,
                              verbose=0,
                              validation_data=(self.x_validation, self.y_validation))

            train_score = model.evaluate(self.x_train, self.y_train, verbose=0)
            val_score = model.evaluate(self.x_validation, self.y_validation, verbose=0)
            test_score = model.evaluate(self.x_test, self.y_test, verbose=0)
            
            #print(test_score)

            resultsDF = pd.DataFrame([train_score,val_score,test_score],
                                     columns=the_columns,
                                     index=["train_score", "val_score", "test_score"],)
            # print(resultsDF)
            test_predictions_baseline = model.predict(self.x_test)
            np.savetxt(os.path.join(self.save_dic,'testing_finalResults_true.out'), self.y_test, delimiter=',')
            np.savetxt(os.path.join(self.save_dic,'testing_finalResults_pred.out'), test_predictions_baseline, delimiter=',')

            return ({
                'loss': test_score[0],  
                'info':  resultsDF.to_dict('index')
            })
        
#             #import IPython; IPython.embed()
#             return ({
#                 'loss': 1-val_score[1], # remember: HpBandSter always minimizes!
#                 'info': {'test accuracy': test_score[1],
#                             'train accuracy': train_score[1],
#                             'validation accuracy': val_score[1],
#                             'number of parameters': model.count_params(),
#                         }

#             })


    @staticmethod
    def get_configspace():
            """
            It builds the configuration space with the needed hyperparameters.
            It is easily possible to implement different types of hyperparameters.
            Beside float-hyperparameters on a log scale, it is also able to handle categorical input parameter.
            :return: ConfigurationsSpace-Object
            """
            cs = CS.ConfigurationSpace()

            lr = CSH.UniformFloatHyperparameter('lr', lower=1e-6, upper=1e-1, default_value='1e-2', log=True)

            # For demonstration purposes, we add different optimizers as categorical hyperparameters.
            # To show how to use conditional hyperparameters with ConfigSpace, we'll add the optimizers 'Adam' and 'SGD'.
            # SGD has a different parameter 'momentum'.
            optimizer = CSH.CategoricalHyperparameter('optimizer', ['Adam', 'SGD'])

            sgd_momentum = CSH.UniformFloatHyperparameter('sgd_momentum', lower=0.0, upper=0.99, default_value=0.9, log=False)

            cs.add_hyperparameters([lr, optimizer, sgd_momentum])



            num_dense_layers =  CSH.UniformIntegerHyperparameter('num_dense_layers', lower=1, upper=3, default_value=2)

            start_neurons_units = CSH.UniformIntegerHyperparameter('start_neurons_units', lower=32, upper=512, default_value=32, log=True)
            dense1_units = CSH.UniformIntegerHyperparameter('dense1_units', lower=8, upper=128, default_value=16, log=True)
            dense2_units = CSH.UniformIntegerHyperparameter('dense2_units', lower=4, upper=64, default_value=8, log=True)

            cs.add_hyperparameters([num_dense_layers, start_neurons_units, dense1_units, dense2_units])

            # start_neurons_activation = CSH.CategoricalHyperparameter('start_neurons_activation', ['relu', 'tanh', 'sigmoid'])
            # dense1_activation = CSH.CategoricalHyperparameter('dense1_activation', ['relu', 'tanh', 'sigmoid'])
            # dense2_activation = CSH.CategoricalHyperparameter('dense2_activation', ['relu', 'tanh', 'sigmoid'])
            # start_neurons_activation = CSH.CategoricalHyperparameter('start_neurons_activation', ['relu'])
            # dense1_activation = CSH.CategoricalHyperparameter('dense1_activation', ['relu'])
            # dense2_activation = CSH.CategoricalHyperparameter('dense2_activation', ['relu'])
            #
            # cs.add_hyperparameters([start_neurons_activation, dense1_activation, dense2_activation])

            dropout1_rate = CSH.UniformFloatHyperparameter('dropout1_rate', lower=0.0, upper=0.9, default_value=0.5, log=False)
            dropout2_rate = CSH.UniformFloatHyperparameter('dropout2_rate', lower=0.0, upper=0.9, default_value=0.5, log=False)

            cs.add_hyperparameters([dropout1_rate, dropout2_rate])


            # The hyperparameter sgd_momentum will be used,if the configuration
            # contains 'SGD' as optimizer.
            cond = CS.EqualsCondition(sgd_momentum, optimizer, 'SGD')
            cs.add_condition(cond)

            # You can also use inequality conditions:
            cond = CS.GreaterThanCondition(dense1_units, num_dense_layers, 1)
            cs.add_condition(cond)

            cond = CS.GreaterThanCondition(dense2_units, num_dense_layers, 2)
            cs.add_condition(cond)

            return cs

# %%
def load_sub_dataset(familiesSet, label_folder, feature_folder, featureType):
    # append all rows of subjects, and their lables
    allFrames = np.array([])
    allLables = np.array([])

    for this_family in familiesSet:
        # F10_Interaction_1_P27_rgb.npy
        onlyfiles = [f for f in os.listdir(feature_folder) if
                       os.path.isfile(os.path.join(feature_folder, f))
                       and f.startswith(this_family + '_')]
        onlyfiles.sort()

        for this_file in onlyfiles:
            currData = np.load(os.path.join(feature_folder,this_file))            
            substr = '_'.join(this_file.split('_')[4:])
            this_lable_file = this_file.replace('_'+substr,'')+'.npy'
            currLabel = np.load(os.path.join(label_folder,this_lable_file))
            cutoff = min(len(currData), len(currLabel))
            currData = currData[:cutoff,:]
            currLabel =currLabel[:cutoff]
            
            
            if allFrames.shape[0] ==0:
                allFrames = currData
                allLables = currLabel
            else:
                allFrames = np.vstack((allFrames, currData))
                allLables = np.hstack((allLables, currLabel))

    return allFrames, allLables

def fix_data(X, y, shuff=False):
    c = Counter(y)
    print('Before:',X.shape, c)
    min_key, min_count = min(c.items(), key=itemgetter(1))
    print(min_key, min_count)
    if min_count<10:
        indx = np.where(y == min_key)
        dub = X[indx]
#         print(dub.shape)
        X = np.vstack((X, np.tile(dub, (10, 1))))
        y = np.hstack((y, np.repeat(min_key,len(dub)*10)))
        print('Dublicated :',X.shape, Counter(y))
    
        #     sm = resample(n_neighbors=max(min_count-1,1))
    sm = sv.MulticlassOversampling(resample())
    if shuff:
        X, y = shuffle(X, y)
        
    #     X, trainy = sm.fit_resample(X, y)
    X, y = sm.sample(X, y)
    print('After:',X.shape, Counter(y))
    
    return X, y

def load_dataset_selectedSubj(trainSubjs, valSubjs, testSubjs, label_folder, feature_folder,\
                              prblemType, featureType, num_classes):
    scaler = MinMaxScaler()
    
    #sampeling method: SMOTE, DeepSMOTE, DeepFake?
    # load all train
    trainX, trainy = load_sub_dataset(trainSubjs, label_folder, feature_folder, featureType)
    trainX = scaler.fit_transform(trainX)
    print('Train Data:')
    trainX, trainy = fix_data(trainX, trainy, shuff=True)


    # load validation
    valX, valy = load_sub_dataset(valSubjs, label_folder, feature_folder, featureType)
    valX = scaler.transform(valX)
    print('Val Data:')
    valX, valy = fix_data(valX, valy, shuff=True)
    
    # load all test
    testX, testy = load_sub_dataset(testSubjs, label_folder, feature_folder, featureType)
    testX = scaler.transform(testX)
    print('Test Data:')
    testX, testy = fix_data(testX, testy, shuff=False)

    # one hot encode y
    trainy = tf.keras.utils.to_categorical(trainy,  num_classes=num_classes)
    valy = tf.keras.utils.to_categorical(valy,  num_classes=num_classes)
    testy = tf.keras.utils.to_categorical(testy,  num_classes=num_classes)
    
    return trainX, trainy, valX, valy , testX, testy, num_classes
    
def create_modlling(label_folder,feature_folder,result_folder, prblemType, featureType, num_classes):    
    # repeat experiment
    temp = {}
    all_trainSubjs = [
        ['F' + str(i) for i in [1, 2, 3, 4, 5, 6, 8]],
        ['F' + str(i) for i in [1, 2, 3, 4, 5, 6, 7]],
        ['F' + str(i) for i in [1, 2, 3, 5, 17, 8]],
        ['F' + str(i) for i in [4, 7, 10, 11, 13, 17]],
        ['F' + str(i) for i in [6, 8, 10, 11, 13, 17]],
    ]
    all_valSubjs = [
        ['F' + str(i) for i in [11, 17]],
        ['F' + str(i) for i in [8, 10]],
        ['F' + str(i) for i in [10, 13, 6]],
        ['F' + str(i) for i in [1, 2, 3]],
        ['F' + str(i) for i in [4, 7, 5]],
    ]
    all_testSubjs = [
        ['F' + str(i) for i in [7, 10, 13]],
        ['F' + str(i) for i in [11, 13, 17]],
        ['F' + str(i) for i in [7, 4, 11]],
        ['F' + str(i) for i in [5, 6, 8]],
        ['F' + str(i) for i in [1, 2, 3]],
    ]
    
    min_budget = 9
    max_budget = 243
    n_iterations = 50
    num_workers = 12

    for r in range(len(all_trainSubjs)):
        shared_directory = result_folder + '_'+ str(r) 
        if os.path.exists(shared_directory):
            print(shared_directory,' already processed')
            continue
        
        print(shared_directory,' under processing')
        classType = os.path.basename(shared_directory)

        # load data
        trainSubjs = all_trainSubjs[r]
        valSubjs = all_valSubjs[r]
        testSubjs = all_testSubjs[r]
        
        trainX, trainy, valX, valy, testX, testy, num_classes = \
            load_dataset_selectedSubj(trainSubjs, valSubjs, testSubjs, \
                                      label_folder, feature_folder, prblemType, featureType, num_classes)
        
        
        n_timesteps, n_features, n_outputs = trainX.shape[0], trainX.shape[1], num_classes        
        
        host = hpns.nic_name_to_host('lo')
        result_logger = hpres.json_result_logger(directory=shared_directory, overwrite=True)
        NS = hpns.NameServer(run_id=classType, host=host, port=0, working_directory=shared_directory)
        ns_host, ns_port = NS.start()
    
        workers = []
        for i in range(num_workers):
            worker = KerasWorker(n_features, n_outputs, prblemType, \
                                 trainX, trainy, valX, valy, testX, testy, \
                                 shared_directory,
                                 run_id=classType,host=host, nameserver=ns_host, nameserver_port=ns_port,
                                 id=i)
            worker.run(background=True)
            workers.append(worker)

        bohb = BOHB(configspace=worker.get_configspace(),
                  run_id=classType,
                  host=host,
                  nameserver=ns_host,
                  nameserver_port=ns_port,
                  result_logger=result_logger,
                  min_budget=min_budget, max_budget=max_budget
                    )
        res = bohb.run(n_iterations=1,  min_n_workers=num_workers)

        id2config = res.get_id2config_mapping()
        incumbent = res.get_incumbent_id()

        print('Best found configuration:', id2config[incumbent]['config'])
        # print('A total of %i unique configurations where sampled.' % len(id2config.keys()))
        # print('A total of %i runs where executed.' % len(res.get_all_runs()))
        # print('Total budget corresponds to %.1f full function evaluations.' % (
        #             sum([r.budget for r in res.get_all_runs()]) / max_budget))

        # store results
        with open(os.path.join(shared_directory, 'results.pkl'), 'wb') as fh:
            pickle.dump(res, fh)

        # shutdown
        bohb.shutdown(shutdown_workers=True)
        NS.shutdown()

# %% [markdown]
# ### modeling handcrafted

# %%
prblemTypes = ['classification']
featureTypes = ['handcrafted_extra']
classes = [2, 3, 5]
fusionTypes = ['2.5','5','5s']
sampling_methods = ['polynom_fit_SMOTE']

permutations=[ prblemTypes, featureTypes, classes, fusionTypes]
all_permutations = list(itertools.product(*permutations))
print(len(all_permutations))
for this_permutation in all_permutations:
    (prblemType, featureType, eng_lvls, fusionType) = this_permutation
    classType = 'round_avg_eng_level' if prblemType == 'classification' else 'avg_eng_level'

    
    print('Working on: ',prblemType, featureType, eng_lvls, fusionType)
    
    label_folder = os.path.join(lables_path,'_'.join([classType,'eng_lvl',prblemType,str(eng_lvls),str(fusionType)]))
    feature_folder = os.path.join(features_path,'_'.join([featureType,'features',fusionType]))
    
    for sampling_method in sampling_methods:

        resample = getattr(__import__("smote_variants", globals(), locals(), [sampling_method], 0), sampling_method)

        #save results like: rgb_classification_9_2.5_none
        result_folder = os.path.join(results_path,'_'.join([featureType,prblemType,str(eng_lvls),fusionType,sampling_method]))

        create_modlling(label_folder,feature_folder,result_folder, prblemType, featureType, eng_lvls)#, divide,fusionType)
# Out:
# 9
# Working on:  classification handcrafted_extra 2 2.5
# ./modelling_results/handcrafted_extra_classification_2_2.5_polynom_fit_SMOTE_0  under processing
# Train Data:
# Before: (18236, 1860) Counter({1.0: 14902, 0.0: 3334})
# 0.0 3334
# After: (28238, 1860) Counter({1.0: 14902, 0.0: 13336})
# Val Data:
# Before: (3467, 1860) Counter({1.0: 3003, 0.0: 464})
# 0.0 464
# After: (5787, 1860) Counter({1.0: 3003, 0.0: 2784})
# Test Data:
# Before: (3916, 1860) Counter({1.0: 3568, 0.0: 348})
# 0.0 348
# After: (7048, 1860) Counter({1.0: 3568, 0.0: 3480})
# 2021-11-09 04:03:40.353697: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-11-09 04:03:40.358891: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcusolver.so.11'; dlerror: libcusolver.so.11: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sharifa/catkin_ws/devel/lib:/usr/local/cuda-11.0/lib64
# 2021-11-09 04:03:40.359645: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudnn.so.8'; dlerror: libcudnn.so.8: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/sharifa/catkin_ws/devel/lib:/usr/local/cuda-11.0/lib64
# 2021-11-09 04:03:40.359668: W tensorflow/core/common_runtime/gpu/gpu_device.cc:1835] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# 2021-11-09 04:03:40.361414: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2021-11-09 04:03:42.267257: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Best found configuration: {'dropout1_rate': 0.48167471074011653, 'dropout2_rate': 0.23768978196725596, 'lr': 3.916614360968384e-05, 'num_dense_layers': 2, 'optimizer': 'Adam', 'start_neurons_units': 156, 'dense1_units': 39}
# ./modelling_results/handcrafted_extra_classification_2_2.5_polynom_fit_SMOTE_1  under processing
# Train Data:
# Before: (17266, 1860) Counter({1.0: 13898, 0.0: 3368})
# 0.0 3368
# After: (27370, 1860) Counter({1.0: 13898, 0.0: 13472})
# Val Data:
# Before: (3892, 1860) Counter({1.0: 3620, 0.0: 272})
# 0.0 272
# After: (7156, 1860) Counter({1.0: 3620, 0.0: 3536})
# Test Data:
# Before: (4461, 1860) Counter({1.0: 3955, 0.0: 506})
# 0.0 506
# After: (8003, 1860) Counter({0.0: 4048, 1.0: 3955})
# Best found configuration: {'dropout1_rate': 0.8902951949717673, 'dropout2_rate': 0.6862640676015757, 'lr': 2.244440300207414e-05, 'num_dense_layers': 1, 'optimizer': 'Adam', 'start_neurons_units': 370}
# ./modelling_results/handcrafted_extra_classification_2_2.5_polynom_fit_SMOTE_2  under processing
# Train Data:
# Before: (12736, 1860) Counter({1.0: 10484, 0.0: 2252})
# 0.0 2252
# After: (21744, 1860) Counter({0.0: 11260, 1.0: 10484})
# Val Data:
# Before: (4472, 1860) Counter({1.0: 3906, 0.0: 566})
# 0.0 566
# After: (7868, 1860) Counter({0.0: 3962, 1.0: 3906})
# Test Data:
# Before: (8411, 1860) Counter({1.0: 7083, 0.0: 1328})
# 0.0 1328
# After: (13723, 1860) Counter({1.0: 7083, 0.0: 6640})
# Best found configuration: {'dropout1_rate': 0.3529597387886591, 'dropout2_rate': 0.5436438371081969, 'lr': 1.3319403340835463e-05, 'num_dense_layers': 1, 'optimizer': 'Adam', 'start_neurons_units': 39}
# ./modelling_results/handcrafted_extra_classification_2_2.5_polynom_fit_SMOTE_3  under processing
# Train Data:
# Before: (12061, 1860) Counter({1.0: 10245, 0.0: 1816})
# 0.0 1816
# After: (21141, 1860) Counter({0.0: 10896, 1.0: 10245})
# Val Data:
# Before: (6185, 1860) Counter({1.0: 5002, 0.0: 1183})
# 0.0 1183
# After: (9734, 1860) Counter({1.0: 5002, 0.0: 4732})
# Test Data:
# Before: (7373, 1860) Counter({1.0: 6226, 0.0: 1147})
# 0.0 1147
# After: (11961, 1860) Counter({1.0: 6226, 0.0: 5735})
# Best found configuration: {'dropout1_rate': 0.7460791039656025, 'dropout2_rate': 0.1208953319912852, 'lr': 5.244007369328478e-05, 'num_dense_layers': 1, 'optimizer': 'Adam', 'start_neurons_units': 375}
# ./modelling_results/handcrafted_extra_classification_2_2.5_polynom_fit_SMOTE_4  under processing
# Train Data:
# Before: (10841, 1860) Counter({1.0: 9632, 0.0: 1209})
# 0.0 1209
# After: (19304, 1860) Counter({0.0: 9672, 1.0: 9632})
# Val Data:
# Before: (8593, 1860) Counter({1.0: 6839, 0.0: 1754})
# 0.0 1754
# After: (13855, 1860) Counter({0.0: 7016, 1.0: 6839})
# Test Data:
# Before: (6185, 1860) Counter({1.0: 5002, 0.0: 1183})
# 0.0 1183
# After: (9734, 1860) Counter({1.0: 5002, 0.0: 4732})
# Best found configuration: {'dropout1_rate': 0.5094096585727843, 'dropout2_rate': 0.4967769480341216, 'lr': 0.0001549285542622481, 'num_dense_layers': 3, 'optimizer': 'SGD', 'start_neurons_units': 294, 'dense1_units': 101, 'dense2_units': 4, 'sgd_momentum': 0.8737174379309559}
# Working on:  classification handcrafted_extra 2 5
# ./modelling_results/handcrafted_extra_classification_2_5_polynom_fit_SMOTE_0  under processing
# Train Data:
# Before: (4548, 1860) Counter({1.0: 3455, 0.0: 1093})
# 0.0 1093
# After: (6734, 1860) Counter({1.0: 3455, 0.0: 3279})
# Val Data:
# Before: (865, 1860) Counter({1.0: 780, 0.0: 85})
# 0.0 85
# After: (1545, 1860) Counter({1.0: 780, 0.0: 765})
# Test Data:
# Before: (978, 1860) Counter({1.0: 852, 0.0: 126})
# 0.0 126
# After: (1734, 1860) Counter({0.0: 882, 1.0: 852})
# Best found configuration: {'dropout1_rate': 0.410760780521699, 'dropout2_rate': 0.7939100013771933, 'lr': 2.500931172482863e-05, 'num_dense_layers': 2, 'optimizer': 'Adam', 'start_neurons_units': 121, 'dense1_units': 113}
# ./modelling_results/handcrafted_extra_classification_2_5_polynom_fit_SMOTE_1  under processing
# Train Data:
# Before: (4307, 1860) Counter({1.0: 3169, 0.0: 1138})
# 0.0 1138
# After: (6583, 1860) Counter({0.0: 3414, 1.0: 3169})
# Val Data:
# Before: (971, 1860) Counter({1.0: 908, 0.0: 63})
# 0.0 63
# After: (1790, 1860) Counter({1.0: 908, 0.0: 882})
# Test Data:
# Before: (1113, 1860) Counter({1.0: 1010, 0.0: 103})
# 0.0 103
# After: (2040, 1860) Counter({0.0: 1030, 1.0: 1010})
# Best found configuration: {'dropout1_rate': 0.7012173388569205, 'dropout2_rate': 0.06471937390972861, 'lr': 0.0013995746536933258, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 388, 'dense1_units': 93, 'sgd_momentum': 0.8678387660062797}
# ./modelling_results/handcrafted_extra_classification_2_5_polynom_fit_SMOTE_2  under processing
# Train Data:
# Before: (3177, 1860) Counter({1.0: 2534, 0.0: 643})
# 0.0 643
# After: (5106, 1860) Counter({0.0: 2572, 1.0: 2534})
# Val Data:
# Before: (1115, 1860) Counter({1.0: 886, 0.0: 229})
# 0.0 229
# After: (1802, 1860) Counter({0.0: 916, 1.0: 886})
# Test Data:
# Before: (2099, 1860) Counter({1.0: 1667, 0.0: 432})
# 0.0 432
# After: (3395, 1860) Counter({0.0: 1728, 1.0: 1667})
# Best found configuration: {'dropout1_rate': 0.05554252421289135, 'dropout2_rate': 0.11700906332077339, 'lr': 4.618688515301363e-06, 'num_dense_layers': 1, 'optimizer': 'Adam', 'start_neurons_units': 221}
# ./modelling_results/handcrafted_extra_classification_2_5_polynom_fit_SMOTE_3  under processing
# Train Data:
# Before: (3010, 1860) Counter({1.0: 2444, 0.0: 566})
# 0.0 566
# After: (4708, 1860) Counter({1.0: 2444, 0.0: 2264})
# Val Data:
# Before: (1543, 1860) Counter({1.0: 1126, 0.0: 417})
# 0.0 417
# After: (2377, 1860) Counter({0.0: 1251, 1.0: 1126})
# Test Data:
# Before: (1838, 1860) Counter({1.0: 1517, 0.0: 321})
# 0.0 321
# After: (3122, 1860) Counter({0.0: 1605, 1.0: 1517})
# Best found configuration: {'dropout1_rate': 0.880635979925503, 'dropout2_rate': 0.46431960226591823, 'lr': 0.00991743808126215, 'num_dense_layers': 2, 'optimizer': 'Adam', 'start_neurons_units': 323, 'dense1_units': 73}
# ./modelling_results/handcrafted_extra_classification_2_5_polynom_fit_SMOTE_4  under processing
# Train Data:
# Before: (2704, 1860) Counter({1.0: 2369, 0.0: 335})
# 0.0 335
# After: (4714, 1860) Counter({1.0: 2369, 0.0: 2345})
# Val Data:
# Before: (2144, 1860) Counter({1.0: 1592, 0.0: 552})
# 0.0 552
# After: (3248, 1860) Counter({0.0: 1656, 1.0: 1592})
# Test Data:
# Before: (1543, 1860) Counter({1.0: 1126, 0.0: 417})
# 0.0 417
# After: (2377, 1860) Counter({0.0: 1251, 1.0: 1126})
# Best found configuration: {'dropout1_rate': 0.16078386628265717, 'dropout2_rate': 0.5456828188579075, 'lr': 8.794383487402078e-05, 'num_dense_layers': 1, 'optimizer': 'SGD', 'start_neurons_units': 454, 'sgd_momentum': 0.596629626213546}
# Working on:  classification handcrafted_extra 2 5s
# ./modelling_results/handcrafted_extra_classification_2_5s_polynom_fit_SMOTE_0  under processing
# Train Data:
# Before: (7797, 1860) Counter({1.0: 6374, 0.0: 1423})
# 0.0 1423
# After: (12066, 1860) Counter({1.0: 6374, 0.0: 5692})
# Val Data:
# Before: (1480, 1860) Counter({1.0: 1283, 0.0: 197})
# 0.0 197
# After: (2662, 1860) Counter({0.0: 1379, 1.0: 1283})
# Test Data:
# Before: (1675, 1860) Counter({1.0: 1526, 0.0: 149})
# 0.0 149
# After: (3016, 1860) Counter({1.0: 1526, 0.0: 1490})
# Best found configuration: {'dropout1_rate': 0.7729103992930816, 'dropout2_rate': 0.6671415932067862, 'lr': 0.0023167181255513447, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 97, 'dense1_units': 90, 'sgd_momentum': 0.4354733452077821}
# ./modelling_results/handcrafted_extra_classification_2_5s_polynom_fit_SMOTE_1  under processing
# Train Data:
# Before: (7382, 1860) Counter({1.0: 5945, 0.0: 1437})
# 0.0 1437
# After: (11693, 1860) Counter({1.0: 5945, 0.0: 5748})
# Val Data:
# Before: (1664, 1860) Counter({1.0: 1547, 0.0: 117})
# 0.0 117
# After: (3068, 1860) Counter({1.0: 1547, 0.0: 1521})
# Test Data:
# Before: (1906, 1860) Counter({1.0: 1691, 0.0: 215})
# 0.0 215
# After: (3411, 1860) Counter({0.0: 1720, 1.0: 1691})
# Best found configuration: {'dropout1_rate': 0.15308535126407444, 'dropout2_rate': 0.8444841606124934, 'lr': 8.428801170187206e-05, 'num_dense_layers': 1, 'optimizer': 'Adam', 'start_neurons_units': 398}
# ./modelling_results/handcrafted_extra_classification_2_5s_polynom_fit_SMOTE_2  under processing
# Train Data:
# Before: (5444, 1860) Counter({1.0: 4482, 0.0: 962})
# 0.0 962
# After: (9292, 1860) Counter({0.0: 4810, 1.0: 4482})
# Val Data:
# Before: (1915, 1860) Counter({1.0: 1672, 0.0: 243})
# 0.0 243
# After: (3373, 1860) Counter({0.0: 1701, 1.0: 1672})
# Test Data:
# Before: (3593, 1860) Counter({1.0: 3029, 0.0: 564})
# 0.0 564
# After: (5849, 1860) Counter({1.0: 3029, 0.0: 2820})
# Best found configuration: {'dropout1_rate': 0.1112214425695892, 'dropout2_rate': 0.3185733158447022, 'lr': 9.088999535688267e-06, 'num_dense_layers': 1, 'optimizer': 'Adam', 'start_neurons_units': 130}
# ./modelling_results/handcrafted_extra_classification_2_5s_polynom_fit_SMOTE_3  under processing
# Train Data:
# Before: (5154, 1860) Counter({1.0: 4381, 0.0: 773})
# 0.0 773
# After: (9019, 1860) Counter({0.0: 4638, 1.0: 4381})
# Val Data:
# Before: (2646, 1860) Counter({1.0: 2140, 0.0: 506})
# 0.0 506
# After: (4164, 1860) Counter({1.0: 2140, 0.0: 2024})
# Test Data:
# Before: (3152, 1860) Counter({1.0: 2662, 0.0: 490})
# 0.0 490
# After: (5112, 1860) Counter({1.0: 2662, 0.0: 2450})
# Best found configuration: {'dropout1_rate': 0.6324934098367755, 'dropout2_rate': 0.2623963443072789, 'lr': 1.5076750077396623e-06, 'num_dense_layers': 2, 'optimizer': 'Adam', 'start_neurons_units': 82, 'dense1_units': 58}
# ./modelling_results/handcrafted_extra_classification_2_5s_polynom_fit_SMOTE_4  under processing
# Train Data:
# Before: (4635, 1860) Counter({1.0: 4119, 0.0: 516})
# 0.0 516
# After: (8247, 1860) Counter({0.0: 4128, 1.0: 4119})
# Val Data:
# Before: (3671, 1860) Counter({1.0: 2924, 0.0: 747})
# 0.0 747
# After: (5912, 1860) Counter({0.0: 2988, 1.0: 2924})
# Test Data:
# Before: (2646, 1860) Counter({1.0: 2140, 0.0: 506})
# 0.0 506
# After: (4164, 1860) Counter({1.0: 2140, 0.0: 2024})
# Best found configuration: {'dropout1_rate': 0.5096814386532899, 'dropout2_rate': 0.17409375571979738, 'lr': 8.165420076365912e-05, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 283, 'dense1_units': 33, 'sgd_momentum': 0.6127265612298548}
# Working on:  classification handcrafted_extra 3 2.5
# ./modelling_results/handcrafted_extra_classification_3_2.5_polynom_fit_SMOTE_0  under processing
# Train Data:
# Before: (18618, 1860) Counter({1.0: 15188, 0.0: 3066, -1.0: 364})
# -1.0 364
# After: (45806, 1860) Counter({0.0: 15330, -1.0: 15288, 1.0: 15188})
# Val Data:
# Before: (3775, 1860) Counter({1.0: 3165, 0.0: 516, -1.0: 94})
# -1.0 94
# After: (9363, 1860) Counter({1.0: 3165, -1.0: 3102, 0.0: 3096})
# Test Data:
# Before: (3976, 1860) Counter({1.0: 3628, 0.0: 346, -1.0: 2})
# -1.0 2
# Dublicated : (3996, 1860) Counter({1.0: 3628, 0.0: 346, -1.0: 22})
# After: (10630, 1860) Counter({1.0: 3628, -1.0: 3542, 0.0: 3460})
# Best found configuration: {'dropout1_rate': 0.7996267910178934, 'dropout2_rate': 0.633558844487364, 'lr': 0.08151403878070436, 'num_dense_layers': 3, 'optimizer': 'SGD', 'start_neurons_units': 358, 'dense1_units': 31, 'dense2_units': 8, 'sgd_momentum': 0.2890889135920406}
# ./modelling_results/handcrafted_extra_classification_3_2.5_polynom_fit_SMOTE_1  under processing
# Train Data:
# Before: (17624, 1860) Counter({1.0: 14170, 0.0: 3088, -1.0: 366})
# -1.0 366
# After: (44250, 1860) Counter({0.0: 15440, -1.0: 14640, 1.0: 14170})
# Val Data:
# Before: (3976, 1860) Counter({1.0: 3694, 0.0: 282})
# 0.0 282
# After: (7360, 1860) Counter({1.0: 3694, 0.0: 3666})
# Test Data:
# Before: (4769, 1860) Counter({1.0: 4117, 0.0: 558, -1.0: 94})
# -1.0 94
# After: (12065, 1860) Counter({1.0: 4117, -1.0: 4042, 0.0: 3906})
# Best found configuration: {'dropout1_rate': 0.5639042746823134, 'dropout2_rate': 0.6688205560182616, 'lr': 0.00014405822305327994, 'num_dense_layers': 1, 'optimizer': 'SGD', 'start_neurons_units': 107, 'sgd_momentum': 0.11269696214895458}
# ./modelling_results/handcrafted_extra_classification_3_2.5_polynom_fit_SMOTE_2  under processing
# Train Data:
# Before: (13052, 1860) Counter({1.0: 10699, 0.0: 2018, -1.0: 335})
# -1.0 335
# After: (31174, 1860) Counter({1.0: 10699, -1.0: 10385, 0.0: 10090})
# Val Data:
# Before: (4473, 1860) Counter({1.0: 3903, 0.0: 508, -1.0: 62})
# -1.0 62
# After: (11935, 1860) Counter({0.0: 4064, -1.0: 3968, 1.0: 3903})
# Test Data:
# Before: (8844, 1860) Counter({1.0: 7379, 0.0: 1402, -1.0: 63})
# -1.0 63
# After: (21571, 1860) Counter({1.0: 7379, -1.0: 7182, 0.0: 7010})
# Best found configuration: {'dropout1_rate': 0.5706671665952341, 'dropout2_rate': 0.8711923493716014, 'lr': 0.01385550667943205, 'num_dense_layers': 3, 'optimizer': 'SGD', 'start_neurons_units': 121, 'dense1_units': 8, 'dense2_units': 5, 'sgd_momentum': 0.21467302638175687}
# ./modelling_results/handcrafted_extra_classification_3_2.5_polynom_fit_SMOTE_3  under processing
# Train Data:
# Before: (12707, 1860) Counter({1.0: 10662, 0.0: 1890, -1.0: 155})
# -1.0 155
# After: (33007, 1860) Counter({0.0: 11340, -1.0: 11005, 1.0: 10662})
# Val Data:
# Before: (6207, 1860) Counter({1.0: 5025, 0.0: 1158, -1.0: 24})
# -1.0 24
# After: (14481, 1860) Counter({1.0: 5025, -1.0: 4824, 0.0: 4632})
# Test Data:
# Before: (7455, 1860) Counter({1.0: 6294, 0.0: 880, -1.0: 281})
# -1.0 281
# After: (18636, 1860) Counter({1.0: 6294, -1.0: 6182, 0.0: 6160})
# Best found configuration: {'dropout1_rate': 0.6011591064325457, 'dropout2_rate': 0.6387942455639373, 'lr': 1.0947007953763064e-05, 'num_dense_layers': 3, 'optimizer': 'Adam', 'start_neurons_units': 447, 'dense1_units': 9, 'dense2_units': 6}
# ./modelling_results/handcrafted_extra_classification_3_2.5_polynom_fit_SMOTE_4  under processing
# Train Data:
# Before: (11230, 1860) Counter({1.0: 9861, 0.0: 1213, -1.0: 156})
# -1.0 156
# After: (29393, 1860) Counter({1.0: 9861, -1.0: 9828, 0.0: 9704})
# Val Data:
# Before: (8932, 1860) Counter({1.0: 7095, 0.0: 1557, -1.0: 280})
# -1.0 280
# After: (22440, 1860) Counter({0.0: 7785, -1.0: 7560, 1.0: 7095})
# Test Data:
# Before: (6207, 1860) Counter({1.0: 5025, 0.0: 1158, -1.0: 24})
# -1.0 24
# After: (14481, 1860) Counter({1.0: 5025, -1.0: 4824, 0.0: 4632})
# Best found configuration: {'dropout1_rate': 0.6272031000090607, 'dropout2_rate': 0.6870961979861319, 'lr': 3.085058954015543e-05, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 424, 'dense1_units': 9, 'sgd_momentum': 0.7361269157788571}
# Working on:  classification handcrafted_extra 3 5
# ./modelling_results/handcrafted_extra_classification_3_5_polynom_fit_SMOTE_0  under processing
# Train Data:
# Before: (9291, 1860) Counter({1.0: 7559, 0.0: 1553, -1.0: 179})
# -1.0 179
# After: (23021, 1860) Counter({0.0: 7765, -1.0: 7697, 1.0: 7559})
# Val Data:
# Before: (1885, 1860) Counter({1.0: 1584, 0.0: 253, -1.0: 48})
# -1.0 48
# After: (4638, 1860) Counter({1.0: 1584, -1.0: 1536, 0.0: 1518})
# Test Data:
# Before: (1984, 1860) Counter({1.0: 1811, 0.0: 172, -1.0: 1})
# -1.0 1
# Dublicated : (1994, 1860) Counter({1.0: 1811, 0.0: 172, -1.0: 11})
# After: (5551, 1860) Counter({0.0: 1892, -1.0: 1848, 1.0: 1811})
# Best found configuration: {'dropout1_rate': 0.8677762160884351, 'dropout2_rate': 0.6722449773875143, 'lr': 0.08942328677480743, 'num_dense_layers': 3, 'optimizer': 'SGD', 'start_neurons_units': 32, 'dense1_units': 89, 'dense2_units': 6, 'sgd_momentum': 0.13341855116323556}
# ./modelling_results/handcrafted_extra_classification_3_5_polynom_fit_SMOTE_1  under processing
# Train Data:
# Before: (8795, 1860) Counter({1.0: 7053, 0.0: 1562, -1.0: 180})
# -1.0 180
# After: (22243, 1860) Counter({0.0: 7810, -1.0: 7380, 1.0: 7053})
# Val Data:
# Before: (1984, 1860) Counter({1.0: 1842, 0.0: 142})
# 0.0 142
# After: (3688, 1860) Counter({0.0: 1846, 1.0: 1842})
# Test Data:
# Before: (2381, 1860) Counter({1.0: 2059, 0.0: 274, -1.0: 48})
# -1.0 48
# After: (6363, 1860) Counter({0.0: 2192, -1.0: 2112, 1.0: 2059})
# Best found configuration: {'dropout1_rate': 0.48411051170847447, 'dropout2_rate': 0.39755579627340637, 'lr': 1.6195051006529281e-06, 'num_dense_layers': 2, 'optimizer': 'Adam', 'start_neurons_units': 225, 'dense1_units': 24}
# ./modelling_results/handcrafted_extra_classification_3_5_polynom_fit_SMOTE_2  under processing
# Train Data:
# Before: (6514, 1860) Counter({1.0: 5327, 0.0: 1024, -1.0: 163})
# -1.0 163
# After: (15663, 1860) Counter({1.0: 5327, -1.0: 5216, -0.0: 5120})
# Val Data:
# Before: (2232, 1860) Counter({1.0: 1943, 0.0: 258, -1.0: 31})
# -1.0 31
# After: (6022, 1860) Counter({0.0: 2064, -1.0: 2015, 1.0: 1943})
# Test Data:
# Before: (4414, 1860) Counter({1.0: 3684, 0.0: 696, -1.0: 34})
# -1.0 34
# After: (10734, 1860) Counter({1.0: 3684, -1.0: 3570, 0.0: 3480})
# Best found configuration: {'dropout1_rate': 0.4470085321739231, 'dropout2_rate': 0.3201947579990171, 'lr': 1.8658303101629904e-06, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 49, 'dense1_units': 20, 'sgd_momentum': 0.6274264134600491}
# ./modelling_results/handcrafted_extra_classification_3_5_polynom_fit_SMOTE_3  under processing
# Train Data:
# Before: (6342, 1860) Counter({1.0: 5325, 0.0: 936, -1.0: 81})
# -1.0 81
# After: (16449, 1860) Counter({0.0: 5616, -1.0: 5508, 1.0: 5325})
# Val Data:
# Before: (3098, 1860) Counter({1.0: 2499, 0.0: 589, -1.0: 10})
# -1.0 10
# After: (7285, 1860) Counter({1.0: 2499, -1.0: 2430, 0.0: 2356})
# Test Data:
# Before: (3720, 1860) Counter({1.0: 3130, 0.0: 453, -1.0: 137})
# -1.0 137
# After: (9452, 1860) Counter({0.0: 3171, -1.0: 3151, 1.0: 3130})
# Best found configuration: {'dropout1_rate': 0.619839210891464, 'dropout2_rate': 0.2978140005454872, 'lr': 0.009763006595664496, 'num_dense_layers': 2, 'optimizer': 'Adam', 'start_neurons_units': 338, 'dense1_units': 8}
# ./modelling_results/handcrafted_extra_classification_3_5_polynom_fit_SMOTE_4  under processing
# Train Data:
# Before: (5605, 1860) Counter({1.0: 4920, 0.0: 606, -1.0: 79})
# -1.0 79
# After: (14666, 1860) Counter({1.0: 4920, -1.0: 4898, 0.0: 4848})
# Val Data:
# Before: (4457, 1860) Counter({1.0: 3535, 0.0: 783, -1.0: 139})
# -1.0 139
# After: (11203, 1860) Counter({0.0: 3915, -1.0: 3753, 1.0: 3535})
# Test Data:
# Before: (3098, 1860) Counter({1.0: 2499, 0.0: 589, -1.0: 10})
# -1.0 10
# After: (7285, 1860) Counter({1.0: 2499, -1.0: 2430, 0.0: 2356})
# Best found configuration: {'dropout1_rate': 0.8969630631044014, 'dropout2_rate': 0.12171772566801861, 'lr': 0.00010196179799452352, 'num_dense_layers': 1, 'optimizer': 'SGD', 'start_neurons_units': 222, 'sgd_momentum': 0.6103562405394523}
# Working on:  classification handcrafted_extra 3 5s
# ./modelling_results/handcrafted_extra_classification_3_5s_polynom_fit_SMOTE_0  under processing
# Train Data:
# Before: (7797, 1860) Counter({1.0: 6374, 0.0: 1269, -1.0: 154})
# -1.0 154
# After: (19033, 1860) Counter({1.0: 6374, 0.0: 6345, -1.0: 6314})
# Val Data:
# Before: (1480, 1860) Counter({1.0: 1283, 0.0: 157, -1.0: 40})
# -1.0 40
# After: (3819, 1860) Counter({1.0: 1283, -1.0: 1280, 0.0: 1256})
# Test Data:
# Before: (1675, 1860) Counter({1.0: 1526, 0.0: 148, -1.0: 1})
# -1.0 1
# Dublicated : (1685, 1860) Counter({1.0: 1526, 0.0: 148, -1.0: 11})
# After: (4513, 1860) Counter({1.0: 1526, -1.0: 1507, 0.0: 1480})
# Best found configuration: {'dropout1_rate': 0.8164980390736347, 'dropout2_rate': 0.568624304681092, 'lr': 0.014136436650740426, 'num_dense_layers': 3, 'optimizer': 'Adam', 'start_neurons_units': 101, 'dense1_units': 19, 'dense2_units': 53}
# ./modelling_results/handcrafted_extra_classification_3_5s_polynom_fit_SMOTE_1  under processing
# Train Data:
# Before: (7382, 1860) Counter({1.0: 5945, 0.0: 1282, -1.0: 155})
# -1.0 155
# After: (18555, 1860) Counter({0.0: 6410, -1.0: 6200, 1.0: 5945})
# Val Data:
# Before: (1664, 1860) Counter({1.0: 1547, 0.0: 117})
# 0.0 117
# After: (3068, 1860) Counter({1.0: 1547, 0.0: 1521})
# Test Data:
# Before: (1906, 1860) Counter({1.0: 1691, 0.0: 175, -1.0: 40})
# -1.0 40
# After: (5161, 1860) Counter({0.0: 1750, -1.0: 1720, 1.0: 1691})
# Best found configuration: {'dropout1_rate': 0.802678977599458, 'dropout2_rate': 0.09409979465802244, 'lr': 1.168681355950423e-06, 'num_dense_layers': 2, 'optimizer': 'Adam', 'start_neurons_units': 382, 'dense1_units': 37}
# ./modelling_results/handcrafted_extra_classification_3_5s_polynom_fit_SMOTE_2  under processing
# Train Data:
# Before: (5444, 1860) Counter({1.0: 4482, 0.0: 819, -1.0: 143})
# -1.0 143
# After: (12867, 1860) Counter({1.0: 4482, -1.0: 4290, 0.0: 4095})
# Val Data:
# Before: (1915, 1860) Counter({1.0: 1672, 0.0: 214, -1.0: 29})
# -1.0 29
# After: (5066, 1860) Counter({0.0: 1712, -1.0: 1682, 1.0: 1672})
# Test Data:
# Before: (3593, 1860) Counter({1.0: 3029, 0.0: 541, -1.0: 23})
# -1.0 23
# After: (9403, 1860) Counter({0.0: 3246, -1.0: 3128, 1.0: 3029})
# Best found configuration: {'dropout1_rate': 0.709930442152381, 'dropout2_rate': 0.10404796235335059, 'lr': 2.4871016157110087e-06, 'num_dense_layers': 3, 'optimizer': 'Adam', 'start_neurons_units': 228, 'dense1_units': 19, 'dense2_units': 13}
# ./modelling_results/handcrafted_extra_classification_3_5s_polynom_fit_SMOTE_3  under processing
# Train Data:
# Before: (5154, 1860) Counter({1.0: 4381, 0.0: 711, -1.0: 62})
# -1.0 62
# After: (12987, 1860) Counter({1.0: 4381, -1.0: 4340, 0.0: 4266})
# Val Data:
# Before: (2646, 1860) Counter({1.0: 2140, 0.0: 496, -1.0: 10})
# -1.0 10
# After: (6184, 1860) Counter({1.0: 2140, -1.0: 2060, 0.0: 1984})
# Test Data:
# Before: (3152, 1860) Counter({1.0: 2662, 0.0: 367, -1.0: 123})
# -1.0 123
# After: (7814, 1860) Counter({1.0: 2662, -1.0: 2583, 0.0: 2569})
# Best found configuration: {'dropout1_rate': 0.781161191587342, 'dropout2_rate': 0.8988475204909397, 'lr': 0.00010648128938318358, 'num_dense_layers': 3, 'optimizer': 'Adam', 'start_neurons_units': 80, 'dense1_units': 13, 'dense2_units': 21}
# ./modelling_results/handcrafted_extra_classification_3_5s_polynom_fit_SMOTE_4  under processing
# Train Data:
# Before: (4635, 1860) Counter({1.0: 4119, 0.0: 447, -1.0: 69})
# -1.0 69
# After: (12213, 1860) Counter({1.0: 4119, -1.0: 4071, -0.0: 4023})
# Val Data:
# Before: (3671, 1860) Counter({1.0: 2924, 0.0: 631, -1.0: 116})
# -1.0 116
# After: (9095, 1860) Counter({0.0: 3155, -1.0: 3016, 1.0: 2924})
# Test Data:
# Before: (2646, 1860) Counter({1.0: 2140, 0.0: 496, -1.0: 10})
# -1.0 10
# After: (6184, 1860) Counter({1.0: 2140, -1.0: 2060, 0.0: 1984})
# Best found configuration: {'dropout1_rate': 0.4512248449551051, 'dropout2_rate': 0.5073653113449955, 'lr': 1.0526460567924462e-06, 'num_dense_layers': 3, 'optimizer': 'Adam', 'start_neurons_units': 504, 'dense1_units': 111, 'dense2_units': 27}
# Working on:  classification handcrafted_extra 5 2.5
# ./modelling_results/handcrafted_extra_classification_5_2.5_polynom_fit_SMOTE_0  under processing
# Train Data:
# Before: (18618, 1860) Counter({1.0: 12138, 0.0: 3063, 2.0: 3053, -1.0: 362, -2.0: 2})
# -2.0 2
# Dublicated : (18638, 1860) Counter({1.0: 12138, 0.0: 3063, 2.0: 3053, -1.0: 362, -2.0: 22})
# After: (61142, 1860) Counter({-1.0: 12308, 0.0: 12252, -2.0: 12232, 2.0: 12212, 1.0: 12138})
# Val Data:
# Before: (3775, 1860) Counter({1.0: 2479, 2.0: 690, 0.0: 512, -1.0: 94})
# -1.0 94
# After: (10431, 1860) Counter({2.0: 2760, -1.0: 2632, 0.0: 2560, 1.0: 2479})
# Test Data:
# Before: (3976, 1860) Counter({1.0: 2335, 2.0: 1294, 0.0: 345, -1.0: 2})
# -1.0 2
# Dublicated : (3996, 1860) Counter({1.0: 2335, 2.0: 1294, 0.0: 345, -1.0: 22})
# After: (9780, 1860) Counter({2.0: 2588, -1.0: 2442, 0.0: 2415, 1.0: 2335})
# Best found configuration: {'dropout1_rate': 0.8575638201731869, 'dropout2_rate': 0.1089484501508634, 'lr': 0.0009281160800380535, 'num_dense_layers': 3, 'optimizer': 'SGD', 'start_neurons_units': 35, 'dense1_units': 17, 'dense2_units': 5, 'sgd_momentum': 0.544439891889296}
# ./modelling_results/handcrafted_extra_classification_5_2.5_polynom_fit_SMOTE_1  under processing
# Train Data:
# Before: (17624, 1860) Counter({1.0: 11337, 0.0: 3086, 2.0: 2835, -1.0: 364, -2.0: 2})
# -2.0 2
# Dublicated : (17644, 1860) Counter({1.0: 11337, 0.0: 3086, 2.0: 2835, -1.0: 364, -2.0: 22})
# After: (58329, 1860) Counter({0.0: 12344, -2.0: 11660, -1.0: 11648, 2.0: 11340, 1.0: 11337})
# Val Data:
# Before: (3976, 1860) Counter({1.0: 2555, 2.0: 1140, 0.0: 281})
# 0.0 281
# After: (7364, 1860) Counter({1.0: 2555, 0.0: 2529, 2.0: 2280})
# Test Data:
# Before: (4769, 1860) Counter({1.0: 3060, 2.0: 1062, 0.0: 553, -1.0: 94})
# -1.0 94
# After: (12760, 1860) Counter({0.0: 3318, -1.0: 3196, 2.0: 3186, 1.0: 3060})
# Best found configuration: {'dropout1_rate': 0.41367495320780334, 'dropout2_rate': 0.19619070524969937, 'lr': 0.000240369634891972, 'num_dense_layers': 1, 'optimizer': 'SGD', 'start_neurons_units': 298, 'sgd_momentum': 0.1218144192447551}
# ./modelling_results/handcrafted_extra_classification_5_2.5_polynom_fit_SMOTE_2  under processing
# Train Data:
# Before: (13052, 1860) Counter({1.0: 7784, 2.0: 2921, 0.0: 2012, -1.0: 335})
# -1.0 335
# After: (32635, 1860) Counter({2.0: 8763, 0.0: 8048, -1.0: 8040, 1.0: 7784})
# Val Data:
# Before: (4473, 1860) Counter({1.0: 3213, 2.0: 692, 0.0: 506, -1.0: 60, -2.0: 2})
# -2.0 2
# Dublicated : (4493, 1860) Counter({1.0: 3213, 2.0: 692, 0.0: 506, -1.0: 60, -2.0: 22})
# After: (17045, 1860) Counter({0.0: 3542, 2.0: 3460, -1.0: 3420, -2.0: 3410, 1.0: 3213})
# Test Data:
# Before: (8844, 1860) Counter({1.0: 5955, 2.0: 1424, 0.0: 1402, -1.0: 63})
# -1.0 63
# After: (22992, 1860) Counter({1.0: 5955, -1.0: 5733, 2.0: 5696, 0.0: 5608})
# Best found configuration: {'dropout1_rate': 0.7844070067357705, 'dropout2_rate': 0.43174649725131947, 'lr': 0.0606936620585775, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 96, 'dense1_units': 9, 'sgd_momentum': 0.8364987574406084}
# ./modelling_results/handcrafted_extra_classification_5_2.5_polynom_fit_SMOTE_3  under processing
# Train Data:
# Before: (12707, 1860) Counter({1.0: 8368, 2.0: 2299, 0.0: 1885, -1.0: 155})
# -1.0 155
# After: (35979, 1860) Counter({0.0: 9425, 2.0: 9196, -1.0: 8990, 1.0: 8368})
# Val Data:
# Before: (6207, 1860) Counter({1.0: 3553, 2.0: 1473, 0.0: 1157, -1.0: 24})
# -1.0 24
# After: (13306, 1860) Counter({1.0: 3553, 0.0: 3471, -1.0: 3336, 2.0: 2946})
# Test Data:
# Before: (7455, 1860) Counter({1.0: 5031, 2.0: 1265, 0.0: 878, -1.0: 279, -2.0: 2})
# -2.0 2
# Dublicated : (7475, 1860) Counter({1.0: 5031, 2.0: 1265, 0.0: 878, -1.0: 279, -2.0: 22})
# After: (25485, 1860) Counter({0.0: 5268, -2.0: 5104, 2.0: 5060, 1.0: 5031, -1.0: 5022})
# Best found configuration: {'dropout1_rate': 0.6253075674059637, 'dropout2_rate': 0.5615097642949021, 'lr': 1.754452381674977e-05, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 228, 'dense1_units': 8, 'sgd_momentum': 0.547791008562492}
# ./modelling_results/handcrafted_extra_classification_5_2.5_polynom_fit_SMOTE_4  under processing
# Train Data:
# Before: (11230, 1860) Counter({1.0: 7524, 2.0: 2344, 0.0: 1206, -1.0: 154, -2.0: 2})
# -2.0 2
# Dublicated : (11250, 1860) Counter({1.0: 7524, 2.0: 2344, 0.0: 1206, -1.0: 154, -2.0: 22})
# After: (36290, 1860) Counter({1.0: 7524, -2.0: 7260, -1.0: 7238, 0.0: 7236, 2.0: 7032})
# Val Data:
# Before: (8932, 1860) Counter({1.0: 5875, 0.0: 1557, 2.0: 1220, -1.0: 280})
# -1.0 280
# After: (24363, 1860) Counter({0.0: 6228, -1.0: 6160, 2.0: 6100, 1.0: 5875})
# Test Data:
# Before: (6207, 1860) Counter({1.0: 3553, 2.0: 1473, 0.0: 1157, -1.0: 24})
# -1.0 24
# After: (13306, 1860) Counter({1.0: 3553, 0.0: 3471, -1.0: 3336, 2.0: 2946})
# Best found configuration: {'dropout1_rate': 0.526779138350341, 'dropout2_rate': 0.8291384297399971, 'lr': 0.004038150254161294, 'num_dense_layers': 3, 'optimizer': 'SGD', 'start_neurons_units': 89, 'dense1_units': 18, 'dense2_units': 5, 'sgd_momentum': 0.23317119673687797}
# Working on:  classification handcrafted_extra 5 5
# ./modelling_results/handcrafted_extra_classification_5_5_polynom_fit_SMOTE_0  under processing
# Train Data:
# Before: (9291, 1860) Counter({1.0: 6033, 0.0: 1544, 2.0: 1534, -1.0: 180})
# -1.0 180
# After: (24465, 1860) Counter({0.0: 6176, 2.0: 6136, -1.0: 6120, 1.0: 6033})
# Val Data:
# Before: (1885, 1860) Counter({1.0: 1236, 2.0: 348, 0.0: 253, -1.0: 48})
# -1.0 48
# After: (5189, 1860) Counter({2.0: 1392, -1.0: 1296, 0.0: 1265, 1.0: 1236})
# Test Data:
# Before: (1984, 1860) Counter({1.0: 1159, 2.0: 654, 0.0: 171})
# 0.0 171
# After: (3664, 1860) Counter({2.0: 1308, 0.0: 1197, 1.0: 1159})
# Best found configuration: {'dropout1_rate': 0.8550845906835497, 'dropout2_rate': 0.13933408971449987, 'lr': 7.688487737704055e-05, 'num_dense_layers': 1, 'optimizer': 'Adam', 'start_neurons_units': 92}
# ./modelling_results/handcrafted_extra_classification_5_5_polynom_fit_SMOTE_1  under processing
# Train Data:
# Before: (8795, 1860) Counter({1.0: 5619, 0.0: 1553, 2.0: 1443, -1.0: 180})
# -1.0 180
# After: (23543, 1860) Counter({0.0: 6212, -1.0: 5940, 2.0: 5772, 1.0: 5619})
# Val Data:
# Before: (1984, 1860) Counter({1.0: 1281, 2.0: 562, 0.0: 141})
# 0.0 141
# After: (3674, 1860) Counter({1.0: 1281, 0.0: 1269, 2.0: 1124})
# Test Data:
# Before: (2381, 1860) Counter({1.0: 1528, 2.0: 531, 0.0: 274, -1.0: 48})
# -1.0 48
# After: (6349, 1860) Counter({0.0: 1644, 2.0: 1593, -1.0: 1584, 1.0: 1528})
# Best found configuration: {'dropout1_rate': 0.028964248800719527, 'dropout2_rate': 0.34370577681424863, 'lr': 1.826597020335292e-05, 'num_dense_layers': 1, 'optimizer': 'SGD', 'start_neurons_units': 133, 'sgd_momentum': 0.938011145490024}
# ./modelling_results/handcrafted_extra_classification_5_5_polynom_fit_SMOTE_2  under processing
# Train Data:
# Before: (6514, 1860) Counter({1.0: 3865, 2.0: 1465, 0.0: 1021, -1.0: 163})
# -1.0 163
# After: (16419, 1860) Counter({2.0: 4395, 0.0: 4084, -1.0: 4075, 1.0: 3865})
# Val Data:
# Before: (2232, 1860) Counter({1.0: 1593, 2.0: 350, 0.0: 257, -1.0: 32})
# -1.0 32
# After: (6517, 1860) Counter({2.0: 1750, -1.0: 1632, 1.0: 1593, 0.0: 1542})
# Test Data:
# Before: (4414, 1860) Counter({1.0: 2970, 2.0: 721, 0.0: 690, -1.0: 33})
# -1.0 33
# After: (11485, 1860) Counter({1.0: 2970, 2.0: 2884, -1.0: 2871, 0.0: 2760})
# Best found configuration: {'dropout1_rate': 0.5071348261494527, 'dropout2_rate': 0.18286630541274804, 'lr': 0.0031153919663367354, 'num_dense_layers': 3, 'optimizer': 'Adam', 'start_neurons_units': 338, 'dense1_units': 24, 'dense2_units': 47}
# ./modelling_results/handcrafted_extra_classification_5_5_polynom_fit_SMOTE_3  under processing
# Train Data:
# Before: (6342, 1860) Counter({1.0: 4169, 2.0: 1163, 0.0: 930, -1.0: 80})
# -1.0 80
# After: (17951, 1860) Counter({2.0: 4652, 0.0: 4650, -1.0: 4480, 1.0: 4169})
# Val Data:
# Before: (3098, 1860) Counter({1.0: 1755, 2.0: 745, 0.0: 588, -1.0: 10})
# -1.0 10
# After: (6679, 1860) Counter({0.0: 1764, 1.0: 1755, -1.0: 1670, 2.0: 1490})
# Test Data:
# Before: (3720, 1860) Counter({1.0: 2504, 2.0: 628, 0.0: 450, -1.0: 138})
# -1.0 138
# After: (10338, 1860) Counter({0.0: 2700, -1.0: 2622, 2.0: 2512, 1.0: 2504})
# Best found configuration: {'dropout1_rate': 0.7714864611358521, 'dropout2_rate': 0.8524398415754154, 'lr': 0.043013478203534856, 'num_dense_layers': 3, 'optimizer': 'Adam', 'start_neurons_units': 64, 'dense1_units': 60, 'dense2_units': 48}
# ./modelling_results/handcrafted_extra_classification_5_5_polynom_fit_SMOTE_4  under processing
# Train Data:
# Before: (5605, 1860) Counter({1.0: 3755, 2.0: 1166, 0.0: 604, -1.0: 80})
# -1.0 80
# After: (14477, 1860) Counter({1.0: 3755, -0.0: 3624, -1.0: 3600, 2.0: 3498})
# Val Data:
# Before: (4457, 1860) Counter({1.0: 2918, 0.0: 776, 2.0: 625, -1.0: 138})
# -1.0 138
# After: (12183, 1860) Counter({2.0: 3125, 0.0: 3104, -1.0: 3036, 1.0: 2918})
# Test Data:
# Before: (3098, 1860) Counter({1.0: 1755, 2.0: 745, 0.0: 588, -1.0: 10})
# -1.0 10
# After: (6679, 1860) Counter({0.0: 1764, 1.0: 1755, -1.0: 1670, 2.0: 1490})
# Best found configuration: {'dropout1_rate': 0.5940871767871069, 'dropout2_rate': 0.31647997302897046, 'lr': 1.8102928805248024e-06, 'num_dense_layers': 2, 'optimizer': 'Adam', 'start_neurons_units': 399, 'dense1_units': 70}
# Working on:  classification handcrafted_extra 5 5s
# ./modelling_results/handcrafted_extra_classification_5_5s_polynom_fit_SMOTE_0  under processing
# Train Data:
# Before: (7797, 1860) Counter({1.0: 5086, 2.0: 1288, 0.0: 1269, -1.0: 153, -2.0: 1})
# -2.0 1
# Dublicated : (7807, 1860) Counter({1.0: 5086, 2.0: 1288, 0.0: 1269, -1.0: 153, -2.0: 11})
# After: (25456, 1860) Counter({2.0: 5152, -2.0: 5093, 1.0: 5086, 0.0: 5076, -1.0: 5049})
# Val Data:
# Before: (1480, 1860) Counter({1.0: 998, 2.0: 285, 0.0: 157, -1.0: 40})
# -1.0 40
# After: (4317, 1860) Counter({2.0: 1140, -0.0: 1099, -1.0: 1080, 1.0: 998})
# Test Data:
# Before: (1675, 1860) Counter({1.0: 974, 2.0: 552, 0.0: 148, -1.0: 1})
# -1.0 1
# Dublicated : (1685, 1860) Counter({1.0: 974, 2.0: 552, 0.0: 148, -1.0: 11})
# After: (4148, 1860) Counter({2.0: 1104, 0.0: 1036, -1.0: 1034, 1.0: 974})
# Best found configuration: {'dropout1_rate': 0.35156321717629135, 'dropout2_rate': 0.7156399012294145, 'lr': 7.8147122348703e-06, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 116, 'dense1_units': 89, 'sgd_momentum': 0.6532483163969355}
# ./modelling_results/handcrafted_extra_classification_5_5s_polynom_fit_SMOTE_1  under processing
# Train Data:
# Before: (7382, 1860) Counter({1.0: 4739, 0.0: 1282, 2.0: 1206, -1.0: 154, -2.0: 1})
# -2.0 1
# Dublicated : (7392, 1860) Counter({1.0: 4739, 0.0: 1282, 2.0: 1206, -1.0: 154, -2.0: 11})
# After: (24525, 1860) Counter({0.0: 5128, -1.0: 4928, -2.0: 4906, 2.0: 4824, 1.0: 4739})
# Val Data:
# Before: (1664, 1860) Counter({1.0: 1070, 2.0: 477, 0.0: 117})
# 0.0 117
# After: (3077, 1860) Counter({1.0: 1070, 0.0: 1053, 2.0: 954})
# Test Data:
# Before: (1906, 1860) Counter({1.0: 1249, 2.0: 442, 0.0: 175, -1.0: 40})
# -1.0 40
# After: (5080, 1860) Counter({2.0: 1326, -1.0: 1280, 1.0: 1249, 0.0: 1225})
# Best found configuration: {'dropout1_rate': 0.5869511097188828, 'dropout2_rate': 0.3570731290491529, 'lr': 0.0005069998757410928, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 55, 'dense1_units': 41, 'sgd_momentum': 0.03806208183398653}
# ./modelling_results/handcrafted_extra_classification_5_5s_polynom_fit_SMOTE_2  under processing
# Train Data:
# Before: (5444, 1860) Counter({1.0: 3256, 2.0: 1226, 0.0: 819, -1.0: 143})
# -1.0 143
# After: (13642, 1860) Counter({2.0: 3678, -1.0: 3432, 0.0: 3276, 1.0: 3256})
# Val Data:
# Before: (1915, 1860) Counter({1.0: 1377, 2.0: 295, 0.0: 214, -1.0: 28, -2.0: 1})
# -2.0 1
# Dublicated : (1925, 1860) Counter({1.0: 1377, 2.0: 295, 0.0: 214, -1.0: 28, -2.0: 11})
# After: (7258, 1860) Counter({0.0: 1498, 2.0: 1475, -1.0: 1456, -2.0: 1452, 1.0: 1377})
# Test Data:
# Before: (3593, 1860) Counter({1.0: 2425, 2.0: 604, 0.0: 541, -1.0: 23})
# -1.0 23
# After: (9351, 1860) Counter({1.0: 2425, 2.0: 2416, -1.0: 2346, 0.0: 2164})
# Best found configuration: {'dropout1_rate': 0.6873188776700668, 'dropout2_rate': 0.5028985017444307, 'lr': 0.003352171583378529, 'num_dense_layers': 3, 'optimizer': 'SGD', 'start_neurons_units': 144, 'dense1_units': 8, 'dense2_units': 38, 'sgd_momentum': 0.9838638959601249}
# ./modelling_results/handcrafted_extra_classification_5_5s_polynom_fit_SMOTE_3  under processing
# Train Data:
# Before: (5154, 1860) Counter({1.0: 3412, 2.0: 969, 0.0: 711, -1.0: 62})
# -1.0 62
# After: (14439, 1860) Counter({2.0: 3876, -1.0: 3596, 0.0: 3555, 1.0: 3412})
# Val Data:
# Before: (2646, 1860) Counter({1.0: 1514, 2.0: 626, 0.0: 496, -1.0: 10})
# -1.0 10
# After: (5674, 1860) Counter({1.0: 1514, 0.0: 1488, -1.0: 1420, 2.0: 1252})
# Test Data:
# Before: (3152, 1860) Counter({1.0: 2132, 2.0: 530, 0.0: 367, -1.0: 122, -2.0: 1})
# -2.0 1
# Dublicated : (3162, 1860) Counter({1.0: 2132, 2.0: 530, 0.0: 367, -1.0: 122, -2.0: 11})
# After: (10817, 1860) Counter({0.0: 2202, -1.0: 2196, -2.0: 2167, 1.0: 2132, 2.0: 2120})
# Best found configuration: {'dropout1_rate': 0.6235686952735555, 'dropout2_rate': 0.7661504266711077, 'lr': 3.882610545916897e-06, 'num_dense_layers': 2, 'optimizer': 'SGD', 'start_neurons_units': 137, 'dense1_units': 8, 'sgd_momentum': 0.7042583760170613}
# ./modelling_results/handcrafted_extra_classification_5_5s_polynom_fit_SMOTE_4  under processing
# Train Data:
# Before: (4635, 1860) Counter({1.0: 3139, 2.0: 980, 0.0: 447, -1.0: 68, -2.0: 1})
# -2.0 1
# Dublicated : (4645, 1860) Counter({1.0: 3139, 2.0: 980, 0.0: 447, -1.0: 68, -2.0: 11})
# After: (15337, 1860) Counter({1.0: 3139, 0.0: 3129, -2.0: 3069, -1.0: 3060, 2.0: 2940})
# Val Data:
# Before: (3671, 1860) Counter({1.0: 2405, 0.0: 631, 2.0: 519, -1.0: 116})
# -1.0 116
# After: (10076, 1860) Counter({2.0: 2595, -1.0: 2552, 0.0: 2524, 1.0: 2405})
# Test Data:
# Before: (2646, 1860) Counter({1.0: 1514, 2.0: 626, 0.0: 496, -1.0: 10})
# -1.0 10
# After: (5674, 1860) Counter({1.0: 1514, 0.0: 1488, -1.0: 1420, 2.0: 1252})
# Best found configuration: {'dropout1_rate': 0.06015896580783383, 'dropout2_rate': 0.6940603069446707, 'lr': 0.00021571196135986294, 'num_dense_layers': 1, 'optimizer': 'SGD', 'start_neurons_units': 215, 'sgd_momentum': 0.4931522613825142}
