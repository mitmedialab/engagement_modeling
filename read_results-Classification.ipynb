# %% [markdown]
# # Reading & analyzing results
# now all the results of all premutions are sored as pkl
#
# we need to get the best results of all

# %% [markdown]
# ### import & vars

# %%
import sys
import numpy as np
import os
import pandas as pd
import itertools
import pickle

from collections import Counter
from sklearn.utils import shuffle
from imblearn.over_sampling import RandomOverSampler as resample

lables_path = './labels/'
features_path = './features/'
results_path = './modelling_results/'

# %% [markdown]
# ### help functions

# %% [markdown]
# ### let's analyze

# %% [markdown]
# ### step 1 -- combine in one guint cvs

# %%
repeats = 0
all_results = pd.DataFrame([])

onlyfolders = [f for f in os.listdir(results_path) if not
                       os.path.isfile(os.path.join(results_path, f))
                       and f.count('classification') > 0]
onlyfolders.sort()
print(onlyfolders)
    
for this_folder in onlyfolders:
    print(this_folder)
    featureType,prblemType,eng_lvls,divide,fusionType,repeats = this_folder.split('_')
    shared_directory = os.path.join(results_path,this_folder)
    
    results_file = os.path.join(shared_directory,'results.pkl')
    if not os.path.exists(results_file):
        print('ERROR: file {} does not exsist'.format(results_file))
        continue
        
    try:
        res = pickle.load(open(results_file, "rb" ))
    except:
        continue
    # id2config = res.get_id2config_mapping()
    # incumbent = res.get_incumbent_id()

    for key in res.data.keys():
        this_data = res[key]
        for bugKey in this_data.results.keys():
            this_results = pd.DataFrame.from_dict(this_data.results[bugKey]['info']).T
            this_results['budget'] = str(bugKey)
            this_results['confID'] = str(key)
            this_results['featureType'] = featureType
            this_results['prblemType'] = prblemType
            this_results['eng_lvls'] = eng_lvls
            this_results['divide'] = divide
            this_results['fusionType'] = fusionType
            this_results['repeats'] = repeats
            
            this_results.set_index(['featureType', 'prblemType', 'confID',\
                                    'budget', 'eng_lvls', 'divide','fusionType','repeats'],\
                                   append=True, inplace=True)
            # cols = this_results.columns.tolist()

            all_results = this_results if len(all_results) ==0 else all_results.append(this_results)


print(all_results.describe())
all_results.to_csv(os.path.join(results_path,'all_classification_results.csv'))
# Out:
# ['flow_classification_3_2.5_none_0', 'flow_classification_3_5_avg_0', 'flow_classification_3_5_conc_0', 'flow_classification_5_2.5_none_0', 'flow_classification_5_5_avg_0', 'flow_classification_5_5_conc_0', 'flow_classification_9_2.5_none_0', 'flow_classification_9_5_avg_0', 'flow_classification_9_5_conc_0', 'rgb_classification_3_2.5_none_0', 'rgb_classification_3_5_avg_0', 'rgb_classification_3_5_conc_0', 'rgb_classification_5_2.5_none_0', 'rgb_classification_5_5_avg_0', 'rgb_classification_5_5_conc_0', 'rgb_classification_9_2.5_none_0', 'rgb_classification_9_5_avg_0', 'rgb_classification_9_5_conc_0', 'twostream_classification_3_2.5_none_0', 'twostream_classification_3_5_avg_0', 'twostream_classification_3_5_conc_0', 'twostream_classification_5_2.5_none_0', 'twostream_classification_5_5_avg_0', 'twostream_classification_5_5_conc_0', 'twostream_classification_9_2.5_none_0', 'twostream_classification_9_5_avg_0', 'twostream_classification_9_5_conc_0']
# flow_classification_3_2.5_none_0
# flow_classification_3_5_avg_0
# flow_classification_3_5_conc_0
# flow_classification_5_2.5_none_0
# flow_classification_5_5_avg_0
# flow_classification_5_5_conc_0
# flow_classification_9_2.5_none_0
# flow_classification_9_5_avg_0
# flow_classification_9_5_conc_0
# rgb_classification_3_2.5_none_0
# rgb_classification_3_5_avg_0
# rgb_classification_3_5_conc_0
# rgb_classification_5_2.5_none_0
# rgb_classification_5_5_avg_0
# rgb_classification_5_5_conc_0
# rgb_classification_9_2.5_none_0
# rgb_classification_9_5_avg_0
# rgb_classification_9_5_conc_0
# twostream_classification_3_2.5_none_0
# twostream_classification_3_5_avg_0
# twostream_classification_3_5_conc_0
# twostream_classification_5_2.5_none_0
# twostream_classification_5_5_avg_0
# twostream_classification_5_5_conc_0
# twostream_classification_9_2.5_none_0
# ERROR: file ./modelling_results/twostream_classification_9_2.5_none_0/results.pkl does not exsist
# twostream_classification_9_5_avg_0
# twostream_classification_9_5_conc_0
#              loss             tp            fp            tn             fn  \
# count  720.000000    3120.000000   3120.000000  3.120000e+03    3120.000000
# mean     3.336500    6343.079167   2014.932692  1.048356e+05   11229.221154
# std      7.742154   10919.078405   2676.109944  1.640346e+05   13738.799323
# min      0.005050       0.000000      0.000000  3.000000e+01       1.000000
# 25%      1.136801      52.750000     49.000000  1.537175e+04    3756.000000
# 50%      1.949076    1368.500000   1292.000000  4.389400e+04    5705.500000
# 75%      2.617124    8371.250000   2978.250000  9.652800e+04   13190.750000
# max    159.585022  117516.000000  41218.000000  2.087555e+06  162533.000000
#
#                acc         prec          rec          auc           BC  \
# count  3120.000000  3120.000000  3120.000000  3120.000000  3120.000000
# mean      0.829616     0.473900     0.271289     0.747346     1.006224
# std       0.139729     0.336631     0.260672     0.165712     0.765981
# min       0.001039     0.000000     0.000000     0.011085     0.009593
# 25%       0.749259     0.210718     0.008054     0.613902     0.688872
# 50%       0.867883     0.450705     0.235807     0.755471     0.798546
# 75%       0.912960     0.810973     0.411191     0.905399     1.074894
# max       3.289805     1.000000     0.997858     0.999998    23.746580
#
#                MCC     thisloss
# count  3120.000000  2400.000000
# mean      0.267995     1.914188
# std       0.265003     1.844825
# min      -0.362235     0.014991
# 25%       0.068158     1.081592
# 50%       0.167861     1.395723
# 75%       0.448931     2.073357
# max       0.997324    19.605118

# %%
all_results.head(-1)
# Out:
#                                                                                                  loss  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.383258
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0        6.669923
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        3.999771
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.377230
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0        7.174591
# ...                                                                                               ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0             NaN
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0             NaN
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0             NaN
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0             NaN
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0             NaN
#
#                                                                                                   tp  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0         2489.0
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0         1215.0
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0         8342.0
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        12027.0
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0         9087.0
# ...                                                                                              ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0         3527.0
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0            0.0
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0            0.0
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        17943.0
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0          123.0
#
#                                                                                                   fp  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0         1856.0
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0         2048.0
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        12895.0
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0         7124.0
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0         3983.0
# ...                                                                                              ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0          400.0
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0            0.0
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0            0.0
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0          305.0
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0          458.0
#
#                                                                                                    tn  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0         43908.0
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0         33558.0
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        240839.0
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        185054.0
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0        124194.0
# ...                                                                                               ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0        258880.0
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0         63000.0
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0         38320.0
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        258975.0
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0         62542.0
#
#                                                                                                   fn  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0         3182.0
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0         3182.0
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        23438.0
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        12002.0
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0         6803.0
# ...                                                                                              ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0        28883.0
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0         7875.0
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0         4790.0
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        14467.0
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0         7752.0
#
#                                                                                                   acc  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.918140
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.868957
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.874443
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.914859
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.927094
# ...                                                                                               ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.899617
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.888887
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.888887
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.949359
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.884162
#
#                                                                                                  prec  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.579889
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.368512
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.390277
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.635176
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.696899
# ...                                                                                               ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.898141
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.000000
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.000000
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.983286
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.211704
#
#                                                                                                   rec  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.438546
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.262727
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.257313
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.500658
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.566549
# ...                                                                                               ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.108824
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.000000
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.000000
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.553625
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.015619
#
#                                                                                                   auc  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.864536
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.812947
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.805181
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.875574
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.966747
# ...                                                                                               ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.918062
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.650656
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.806783
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.992899
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.642169
#
#                                                                                                    BC  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.828521
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.941871
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.897990
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        1.229452
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0        1.026445
# ...                                                                                               ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0        1.132194
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0        1.004195
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.925190
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        3.706673
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0        1.404624
#
#                                                                                                   MCC  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.238149
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.052046
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0        0.149829
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.385543
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0        0.461533
# ...                                                                                               ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.487202
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.043221
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0        0.158530
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.882456
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.061054
#
#                                                                                              thisloss
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 0)  9.0    3        2.5    none       0             NaN
# val_score   flow        classification (0, 0, 0)  9.0    3        2.5    none       0             NaN
# test_score  flow        classification (0, 0, 0)  9.0    3        2.5    none       0             NaN
# train_score flow        classification (0, 0, 0)  27.0   3        2.5    none       0             NaN
# val_score   flow        classification (0, 0, 0)  27.0   3        2.5    none       0             NaN
# ...                                                                                               ...
# train_score twostream   classification (0, 0, 26) 9.0    9        5      conc       0        1.189201
# val_score   twostream   classification (0, 0, 26) 9.0    9        5      conc       0        2.499588
# test_score  twostream   classification (0, 0, 26) 9.0    9        5      conc       0        1.698325
# train_score twostream   classification (0, 0, 26) 27.0   9        5      conc       0        0.536242
# val_score   twostream   classification (0, 0, 26) 27.0   9        5      conc       0        3.150582
#
# [3119 rows x 12 columns]

# %%
repeats = 0
best_results = pd.DataFrame([])

onlyfolders = [f for f in os.listdir(results_path) if not
                       os.path.isfile(os.path.join(results_path, f))
                       and f.count('classification') > 0]
onlyfolders.sort()
    
for this_folder in onlyfolders:
    print(this_folder)
    #featureType,prblemType,eng_lvls,divide,fusionType,repeats = this_folder.split('_')
    try:
        featureType,prblemType,eng_lvls,divide,fusionType,repeats = this_folder.split('_')
    except:
        featureType,prblemType,eng_lvls,divide,repeats = this_folder.split('_')
        fusionType = 'none'
        pass
    shared_directory = os.path.join(results_path,this_folder)
    
    results_file = os.path.join(shared_directory,'results.pkl')
    if not os.path.exists(results_file):
        print('ERROR: file {} does not exsist'.format(results_file))
        continue
        
    try:
        res = pickle.load(open(results_file, "rb" ))
    except:
        continue
    id2config = res.get_id2config_mapping()
    incumbent = res.get_incumbent_id()
    

    this_data = res[incumbent]
    new_dic = dict(zip([key for key in this_data.results.keys()],\
                       [this_data.results[k]['loss'] for k in this_data.results.keys()]))
 
    bugKey = min(new_dic, key=new_dic.get)
    
    this_results = pd.DataFrame.from_dict(this_data.results[bugKey]['info']).T
    this_results['budget'] = str(bugKey)
    this_results['confID'] = str(incumbent)
    this_results['featureType'] = featureType
    this_results['prblemType'] = prblemType
    this_results['eng_lvls'] = eng_lvls
    this_results['divide'] = divide
    this_results['fusionType'] = fusionType
    this_results['repeats'] = repeats

    this_results.set_index(['featureType', 'prblemType', 'confID',\
                            'budget', 'eng_lvls', 'divide','fusionType','repeats'],\
                           append=True, inplace=True)
    # cols = this_results.columns.tolist()

    best_results = best_results if len(this_results) ==0 else best_results.append(this_results)


print(best_results)
best_results.to_csv(os.path.join(results_path,'best_classification_results.csv'))
# Out:
# flow_classification_3_2.5_none_0
# flow_classification_3_5_avg_0
# flow_classification_3_5_conc_0
# flow_classification_5_2.5_none_0
# flow_classification_5_5_avg_0
# flow_classification_5_5_conc_0
# flow_classification_9_2.5_none_0
# flow_classification_9_5_avg_0
# flow_classification_9_5_conc_0
# handcrafted_classification_3_2.5_0
# handcrafted_classification_3_5_0
# handcrafted_classification_3_5s_0
# handcrafted_classification_5_2.5_0
# handcrafted_classification_5_5_0
# handcrafted_classification_5_5s_0
# handcrafted_classification_9_2.5_0
# handcrafted_classification_9_5_0
# handcrafted_classification_9_5s_0
# rgb_classification_3_2.5_none_0
# rgb_classification_3_5_avg_0
# rgb_classification_3_5_conc_0
# rgb_classification_5_2.5_none_0
# rgb_classification_5_5_avg_0
# rgb_classification_5_5_conc_0
# rgb_classification_9_2.5_none_0
# rgb_classification_9_5_avg_0
# rgb_classification_9_5_conc_0
# twostream_classification_3_2.5_none_0
# twostream_classification_3_5_avg_0
# twostream_classification_3_5_conc_0
# twostream_classification_5_2.5_none_0
# twostream_classification_5_5_avg_0
# twostream_classification_5_5_conc_0
# twostream_classification_9_2.5_none_0
# ERROR: file ./modelling_results/twostream_classification_9_2.5_none_0/results.pkl does not exsist
# twostream_classification_9_5_avg_0
# twostream_classification_9_5_conc_0
#                                                                                                  loss  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.160954
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0        5.498668
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0        2.626430
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0             NaN
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0             NaN
# ...                                                                                               ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0             NaN
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0             NaN
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0             NaN
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0             NaN
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0             NaN
#
#                                                                                                   tp  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        43341.0
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0         3487.0
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0         3909.0
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0            0.0
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0            0.0
# ...                                                                                              ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0          319.0
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0           33.0
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0         9402.0
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0          212.0
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0           64.0
#
#                                                                                                  fp  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        2024.0
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0        5929.0
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0        4921.0
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0           0.0
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0           0.0
# ...                                                                                             ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0         371.0
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0         154.0
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        2332.0
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0         228.0
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0         153.0
#
#                                                                                                    tn  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        362680.0
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0         70295.0
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0         82151.0
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0         45372.0
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0          9528.0
# ...                                                                                               ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0         62629.0
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0         38166.0
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        256948.0
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0         62772.0
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0         38167.0
#
#                                                                                                   fn  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0         2247.0
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0         6041.0
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0         6975.0
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0        22686.0
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0         4764.0
# ...                                                                                              ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0         7556.0
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0         4757.0
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        23008.0
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0         7663.0
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0         4726.0
#
#                                                                                                   acc  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.989588
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.860411
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.878558
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.666663
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.666666
# ...                                                                                               ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.888155
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.886081
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.913127
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.888662
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.886824
#
#                                                                                                  prec  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.955384
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.370327
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.442695
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.000000
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.000000
# ...                                                                                               ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.462319
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.176471
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.801261
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.481818
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.294931
#
#                                                                                                   rec  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.950711
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.365974
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.359151
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.000000
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.000000
# ...                                                                                               ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.040508
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.006889
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.290096
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.026921
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.013361
#
#                                                                                                   auc  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.998601
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.741171
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.819735
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.545662
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.481232
# ...                                                                                               ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.732033
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.794722
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.929350
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.728679
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.800706
#
#                                                                                                    BC  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        1.167163
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0        1.819823
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0        1.515721
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.688631
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.689354
# ...                                                                                               ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.666265
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.631450
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.751282
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.773980
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.770606
#
#                                                                                                   MCC  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.930345
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.068163
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0        0.068861
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0        0.051719
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0       -0.077230
# ...                                                                                               ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.197147
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0        0.094405
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.510386
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.192125
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0        0.081399
#
#                                                                                              thisloss
#             featureType prblemType     confID     budget eng_lvls divide fusionType repeats
# train_score flow        classification (0, 0, 24) 243.0  3        2.5    none       0             NaN
# val_score   flow        classification (0, 0, 24) 243.0  3        2.5    none       0             NaN
# test_score  flow        classification (0, 0, 24) 243.0  3        2.5    none       0             NaN
# train_score flow        classification (0, 0, 21) 81.0   3        5      avg        0        1.095756
# val_score   flow        classification (0, 0, 21) 81.0   3        5      avg        0        1.099975
# ...                                                                                               ...
#             twostream   classification (0, 0, 0)  27.0   9        5      avg        0        1.965583
# test_score  twostream   classification (0, 0, 0)  27.0   9        5      avg        0        1.685005
# train_score twostream   classification (0, 0, 2)  27.0   9        5      conc       0        1.107728
# val_score   twostream   classification (0, 0, 2)  27.0   9        5      conc       0        1.949448
# test_score  twostream   classification (0, 0, 2)  27.0   9        5      conc       0        1.663726
#
# [105 rows x 12 columns]
