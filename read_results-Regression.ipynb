# %% [markdown]
# # Reading & analyzing results
# now all the results of all premutions are sored as pkl
#
# we need to get the best results of all

# %% [markdown]
# ### import & vars

# %%
import sys
import numpy as np
import os
import pandas as pd
import itertools
import pickle

from collections import Counter
from sklearn.utils import shuffle
from imblearn.over_sampling import RandomOverSampler as resample

lables_path = './labels/'
features_path = './features/'
results_path = './modelling_results/'

# %% [markdown]
# ### help functions

# %% [markdown]
# ### let's analyze

# %% [markdown]
# ### step 1 -- combine in one guint cvs

# %%
repeats = 0
all_results = pd.DataFrame([])

onlyfolders = [f for f in os.listdir(results_path) if not
                       os.path.isfile(os.path.join(results_path, f))
                       and f.count('regression') > 0]
onlyfolders.sort()
print(onlyfolders)
    
for this_folder in onlyfolders:
    print(this_folder)
    featureType,prblemType,eng_lvls,divide,fusionType,repeats = this_folder.split('_')
    shared_directory = os.path.join(results_path,this_folder)
    
    results_file = os.path.join(shared_directory,'results.pkl')
    if not os.path.exists(results_file):
        print('ERROR: file {} does not exsist'.format(results_file))
        continue
        
    try:
        res = pickle.load(open(results_file, "rb" ))
    except:
        continue
    # id2config = res.get_id2config_mapping()
    # incumbent = res.get_incumbent_id()

    for key in res.data.keys():
        this_data = res[key]
        for bugKey in this_data.results.keys():
            this_results = pd.DataFrame.from_dict(this_data.results[bugKey]['info']).T
            this_results['budget'] = str(bugKey)
            this_results['confID'] = str(key)
            this_results['featureType'] = featureType
            this_results['prblemType'] = prblemType
            this_results['eng_lvls'] = eng_lvls
            this_results['divide'] = divide
            this_results['fusionType'] = fusionType
            this_results['repeats'] = repeats
            
            this_results.set_index(['featureType', 'prblemType', 'confID',\
                                    'budget', 'eng_lvls', 'divide','fusionType','repeats'],\
                                   append=True, inplace=True)
            # cols = this_results.columns.tolist()

            all_results = this_results if len(all_results) ==0 else all_results.append(this_results)


print(all_results.describe())
all_results.to_csv(os.path.join(results_path,'all_regression_results.csv'))
# Out:
# ['flow_regression_3_2.5_none_0', 'flow_regression_3_5_avg_0', 'flow_regression_3_5_conc_0', 'flow_regression_5_2.5_none_0', 'flow_regression_5_5_avg_0', 'flow_regression_5_5_conc_0', 'flow_regression_9_2.5_none_0', 'flow_regression_9_5_avg_0', 'flow_regression_9_5_conc_0', 'rgb_regression_3_2.5_none_0', 'rgb_regression_3_5_avg_0', 'rgb_regression_3_5_conc_0', 'rgb_regression_5_2.5_none_0', 'rgb_regression_5_5_avg_0', 'rgb_regression_5_5_conc_0', 'rgb_regression_9_2.5_none_0', 'rgb_regression_9_5_avg_0', 'rgb_regression_9_5_conc_0', 'twostream_regression_3_2.5_none_0', 'twostream_regression_3_5_avg_0', 'twostream_regression_3_5_conc_0', 'twostream_regression_5_2.5_none_0', 'twostream_regression_5_5_avg_0', 'twostream_regression_5_5_conc_0', 'twostream_regression_9_2.5_none_0', 'twostream_regression_9_5_avg_0', 'twostream_regression_9_5_conc_0']
# flow_regression_3_2.5_none_0
# flow_regression_3_5_avg_0
# flow_regression_3_5_conc_0
# flow_regression_5_2.5_none_0
# flow_regression_5_5_avg_0
# flow_regression_5_5_conc_0
# flow_regression_9_2.5_none_0
# flow_regression_9_5_avg_0
# flow_regression_9_5_conc_0
# rgb_regression_3_2.5_none_0
# rgb_regression_3_5_avg_0
# rgb_regression_3_5_conc_0
# rgb_regression_5_2.5_none_0
# rgb_regression_5_5_avg_0
# rgb_regression_5_5_conc_0
# rgb_regression_9_2.5_none_0
# rgb_regression_9_5_avg_0
# rgb_regression_9_5_conc_0
# twostream_regression_3_2.5_none_0
# twostream_regression_3_5_avg_0
# twostream_regression_3_5_conc_0
# twostream_regression_5_2.5_none_0
# twostream_regression_5_5_avg_0
# twostream_regression_5_5_conc_0
# twostream_regression_9_2.5_none_0
# twostream_regression_9_5_avg_0
# twostream_regression_9_5_conc_0
#               loss          mae     maperc_e      mslog_e  CosineSimilarity  \
# count  3240.000000  3240.000000  3240.000000  3240.000000       3240.000000
# mean     16.997108     3.498346    90.457810     1.848280         -2.270946
# std      14.815256     1.731945     7.316031     1.083315          0.572032
# min       2.798880     1.543885    78.610085     0.610448         -3.000000
# 25%       3.511553     1.736162    81.645180     0.713384         -2.992671
# 50%       9.958754     3.019777    93.142395     1.571579         -2.236061
# 75%      34.529339     5.534406    97.629829     3.118651         -1.732052
# max      43.525288     6.257136    97.963737     3.659202         -1.000000
#
#              Huber      LogCosh
# count  3240.000000  3240.000000
# mean      3.003089     2.835864
# std       1.726898     1.703544
# min       1.066025     0.948171
# 25%       1.252374     1.117250
# 50%       2.519780     2.332263
# 75%       5.034407     4.843174
# max       5.757162     5.565507

# %%
all_results.head(-1)
# Out:
#                                                                                               loss  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 0)  9.0    3        2.5    none       0         3.673772
# val_score   flow        regression (0, 0, 0)  9.0    3        2.5    none       0         2.899796
# test_score  flow        regression (0, 0, 0)  9.0    3        2.5    none       0         2.801099
# train_score flow        regression (0, 0, 1)  9.0    3        2.5    none       0         3.673928
# val_score   flow        regression (0, 0, 1)  9.0    3        2.5    none       0         2.900024
# ...                                                                                            ...
# train_score twostream   regression (0, 0, 25) 9.0    9        5      conc       0        41.679325
# val_score   twostream   regression (0, 0, 25) 9.0    9        5      conc       0        34.954967
# test_score  twostream   regression (0, 0, 25) 9.0    9        5      conc       0        34.511696
# train_score twostream   regression (0, 0, 26) 9.0    9        5      conc       0        41.679348
# val_score   twostream   regression (0, 0, 26) 9.0    9        5      conc       0        34.954994
#
#                                                                                               mae  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 0)  9.0    3        2.5    none       0        1.788266
# val_score   flow        regression (0, 0, 0)  9.0    3        2.5    none       0        1.548500
# test_score  flow        regression (0, 0, 0)  9.0    3        2.5    none       0        1.597556
# train_score flow        regression (0, 0, 1)  9.0    3        2.5    none       0        1.788266
# val_score   flow        regression (0, 0, 1)  9.0    3        2.5    none       0        1.548500
# ...                                                                                           ...
# train_score twostream   regression (0, 0, 25) 9.0    9        5      conc       0        6.101916
# val_score   twostream   regression (0, 0, 25) 9.0    9        5      conc       0        5.520540
# test_score  twostream   regression (0, 0, 25) 9.0    9        5      conc       0        5.684500
# train_score twostream   regression (0, 0, 26) 9.0    9        5      conc       0        6.101916
# val_score   twostream   regression (0, 0, 26) 9.0    9        5      conc       0        5.520540
#
#                                                                                           maperc_e  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 0)  9.0    3        2.5    none       0        81.538307
# val_score   flow        regression (0, 0, 0)  9.0    3        2.5    none       0        78.610085
# test_score  flow        regression (0, 0, 0)  9.0    3        2.5    none       0        81.645172
# train_score flow        regression (0, 0, 1)  9.0    3        2.5    none       0        81.538307
# val_score   flow        regression (0, 0, 1)  9.0    3        2.5    none       0        78.610085
# ...                                                                                            ...
# train_score twostream   regression (0, 0, 25) 9.0    9        5      conc       0        97.886559
# val_score   twostream   regression (0, 0, 25) 9.0    9        5      conc       0        97.629829
# test_score  twostream   regression (0, 0, 25) 9.0    9        5      conc       0        97.963737
# train_score twostream   regression (0, 0, 26) 9.0    9        5      conc       0        97.886559
# val_score   twostream   regression (0, 0, 26) 9.0    9        5      conc       0        97.629829
#
#                                                                                           mslog_e  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 0)  9.0    3        2.5    none       0        0.737145
# val_score   flow        regression (0, 0, 0)  9.0    3        2.5    none       0        0.613339
# test_score  flow        regression (0, 0, 0)  9.0    3        2.5    none       0        0.625907
# train_score flow        regression (0, 0, 1)  9.0    3        2.5    none       0        0.737307
# val_score   flow        regression (0, 0, 1)  9.0    3        2.5    none       0        0.613563
# ...                                                                                           ...
# train_score twostream   regression (0, 0, 25) 9.0    9        5      conc       0        3.422715
# val_score   twostream   regression (0, 0, 25) 9.0    9        5      conc       0        3.112443
# test_score  twostream   regression (0, 0, 25) 9.0    9        5      conc       0        3.242527
# train_score twostream   regression (0, 0, 26) 9.0    9        5      conc       0        3.422745
# val_score   twostream   regression (0, 0, 26) 9.0    9        5      conc       0        3.112501
#
#                                                                                          CosineSimilarity  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 0)  9.0    3        2.5    none       0               -1.731945
# val_score   flow        regression (0, 0, 0)  9.0    3        2.5    none       0               -1.731891
# test_score  flow        regression (0, 0, 0)  9.0    3        2.5    none       0               -1.731944
# train_score flow        regression (0, 0, 1)  9.0    3        2.5    none       0               -1.730764
# val_score   flow        regression (0, 0, 1)  9.0    3        2.5    none       0               -1.730122
# ...                                                                                                   ...
# train_score twostream   regression (0, 0, 25) 9.0    9        5      conc       0               -3.000000
# val_score   twostream   regression (0, 0, 25) 9.0    9        5      conc       0               -3.000000
# test_score  twostream   regression (0, 0, 25) 9.0    9        5      conc       0               -3.000000
# train_score twostream   regression (0, 0, 26) 9.0    9        5      conc       0               -2.998413
# val_score   twostream   regression (0, 0, 26) 9.0    9        5      conc       0               -2.996684
#
#                                                                                             Huber  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 0)  9.0    3        2.5    none       0        1.302690
# val_score   flow        regression (0, 0, 0)  9.0    3        2.5    none       0        1.071501
# test_score  flow        regression (0, 0, 0)  9.0    3        2.5    none       0        1.097630
# train_score flow        regression (0, 0, 1)  9.0    3        2.5    none       0        1.302698
# val_score   flow        regression (0, 0, 1)  9.0    3        2.5    none       0        1.071536
# ...                                                                                           ...
# train_score twostream   regression (0, 0, 25) 9.0    9        5      conc       0        5.601917
# val_score   twostream   regression (0, 0, 25) 9.0    9        5      conc       0        5.020539
# test_score  twostream   regression (0, 0, 25) 9.0    9        5      conc       0        5.184497
# train_score twostream   regression (0, 0, 26) 9.0    9        5      conc       0        5.601917
# val_score   twostream   regression (0, 0, 26) 9.0    9        5      conc       0        5.020539
#
#                                                                                           LogCosh
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 0)  9.0    3        2.5    none       0        1.162707
# val_score   flow        regression (0, 0, 0)  9.0    3        2.5    none       0        0.953383
# test_score  flow        regression (0, 0, 0)  9.0    3        2.5    none       0        0.961963
# train_score flow        regression (0, 0, 1)  9.0    3        2.5    none       0        1.162718
# val_score   flow        regression (0, 0, 1)  9.0    3        2.5    none       0        0.953413
# ...                                                                                           ...
# train_score twostream   regression (0, 0, 25) 9.0    9        5      conc       0        5.409942
# val_score   twostream   regression (0, 0, 25) 9.0    9        5      conc       0        4.829145
# test_score  twostream   regression (0, 0, 25) 9.0    9        5      conc       0        4.991432
# train_score twostream   regression (0, 0, 26) 9.0    9        5      conc       0        5.409942
# val_score   twostream   regression (0, 0, 26) 9.0    9        5      conc       0        4.829145
#
# [3239 rows x 7 columns]

# %%
repeats = 0
best_results = pd.DataFrame([])

onlyfolders = [f for f in os.listdir(results_path) if not
                       os.path.isfile(os.path.join(results_path, f))
                       and f.count('regression') > 0]
onlyfolders.sort()
    
for this_folder in onlyfolders:
    print(this_folder)
    try:
        featureType,prblemType,eng_lvls,divide,fusionType,repeats = this_folder.split('_')
    except:
        featureType,prblemType,eng_lvls,divide,repeats = this_folder.split('_')
        fusionType = 'none'
    
    shared_directory = os.path.join(results_path,this_folder)
    
    results_file = os.path.join(shared_directory,'results.pkl')
    if not os.path.exists(results_file):
        print('ERROR: file {} does not exsist'.format(results_file))
        continue
        
    try:
        res = pickle.load(open(results_file, "rb" ))
    except:
        continue
    id2config = res.get_id2config_mapping()
    incumbent = res.get_incumbent_id()
    

    this_data = res[incumbent]
    new_dic = dict(zip([key for key in this_data.results.keys()],\
                       [this_data.results[k]['loss'] for k in this_data.results.keys()]))
 
    bugKey = min(new_dic, key=new_dic.get)
    
    this_results = pd.DataFrame.from_dict(this_data.results[bugKey]['info']).T
    this_results['budget'] = str(bugKey)
    this_results['confID'] = str(incumbent)
    this_results['featureType'] = featureType
    this_results['prblemType'] = prblemType
    this_results['eng_lvls'] = eng_lvls
    this_results['divide'] = divide
    this_results['fusionType'] = fusionType
    this_results['repeats'] = repeats

    this_results.set_index(['featureType', 'prblemType', 'confID',\
                            'budget', 'eng_lvls', 'divide','fusionType','repeats'],\
                           append=True, inplace=True)
    # cols = this_results.columns.tolist()

    best_results = best_results if len(this_results) ==0 else best_results.append(this_results)


print(best_results)
best_results.to_csv(os.path.join(results_path,'best_regression_results.csv'))
# Out:
# flow_regression_3_2.5_none_0
# flow_regression_3_5_avg_0
# flow_regression_3_5_conc_0
# flow_regression_5_2.5_none_0
# flow_regression_5_5_avg_0
# flow_regression_5_5_conc_0
# flow_regression_9_2.5_none_0
# flow_regression_9_5_avg_0
# flow_regression_9_5_conc_0
# handcrafted_regression_3_2.5_0
# handcrafted_regression_3_5_0
# handcrafted_regression_3_5s_0
# handcrafted_regression_5_2.5_0
# ERROR: file ./modelling_results/handcrafted_regression_5_2.5_0/results.pkl does not exsist
# handcrafted_regression_5_5_0
# handcrafted_regression_5_5s_0
# handcrafted_regression_9_2.5_0
# handcrafted_regression_9_5_0
# handcrafted_regression_9_5s_0
# rgb_regression_3_2.5_none_0
# rgb_regression_3_5_avg_0
# rgb_regression_3_5_conc_0
# rgb_regression_5_2.5_none_0
# rgb_regression_5_5_avg_0
# rgb_regression_5_5_conc_0
# rgb_regression_9_2.5_none_0
# rgb_regression_9_5_avg_0
# rgb_regression_9_5_conc_0
# twostream_regression_3_2.5_none_0
# twostream_regression_3_5_avg_0
# twostream_regression_3_5_conc_0
# twostream_regression_5_2.5_none_0
# twostream_regression_5_5_avg_0
# twostream_regression_5_5_conc_0
# twostream_regression_9_2.5_none_0
# twostream_regression_9_5_avg_0
# twostream_regression_9_5_conc_0
#                                                                                               loss  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 20) 9.0    3        2.5    none       0         3.673761
# val_score   flow        regression (0, 0, 20) 9.0    3        2.5    none       0         2.899776
# test_score  flow        regression (0, 0, 20) 9.0    3        2.5    none       0         2.801070
# train_score flow        regression (0, 0, 9)  81.0   3        5      avg        0         3.530279
# val_score   flow        regression (0, 0, 9)  81.0   3        5      avg        0         2.880023
# ...                                                                                            ...
#             twostream   regression (0, 0, 3)  9.0    9        5      avg        0        34.954967
# test_score  twostream   regression (0, 0, 3)  9.0    9        5      avg        0        34.511696
# train_score twostream   regression (0, 0, 1)  9.0    9        5      conc       0        41.679333
# val_score   twostream   regression (0, 0, 1)  9.0    9        5      conc       0        34.954967
# test_score  twostream   regression (0, 0, 1)  9.0    9        5      conc       0        34.511696
#
#                                                                                               mae  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 20) 9.0    3        2.5    none       0        1.788266
# val_score   flow        regression (0, 0, 20) 9.0    3        2.5    none       0        1.548500
# test_score  flow        regression (0, 0, 20) 9.0    3        2.5    none       0        1.597556
# train_score flow        regression (0, 0, 9)  81.0   3        5      avg        0        1.742624
# val_score   flow        regression (0, 0, 9)  81.0   3        5      avg        0        1.543885
# ...                                                                                           ...
#             twostream   regression (0, 0, 3)  9.0    9        5      avg        0        5.520540
# test_score  twostream   regression (0, 0, 3)  9.0    9        5      avg        0        5.684500
# train_score twostream   regression (0, 0, 1)  9.0    9        5      conc       0        6.101916
# val_score   twostream   regression (0, 0, 1)  9.0    9        5      conc       0        5.520540
# test_score  twostream   regression (0, 0, 1)  9.0    9        5      conc       0        5.684500
#
#                                                                                           maperc_e  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 20) 9.0    3        2.5    none       0        81.538307
# val_score   flow        regression (0, 0, 20) 9.0    3        2.5    none       0        78.610085
# test_score  flow        regression (0, 0, 20) 9.0    3        2.5    none       0        81.645180
# train_score flow        regression (0, 0, 9)  81.0   3        5      avg        0        81.026726
# val_score   flow        regression (0, 0, 9)  81.0   3        5      avg        0        78.668510
# ...                                                                                            ...
#             twostream   regression (0, 0, 3)  9.0    9        5      avg        0        97.629829
# test_score  twostream   regression (0, 0, 3)  9.0    9        5      avg        0        97.963737
# train_score twostream   regression (0, 0, 1)  9.0    9        5      conc       0        97.886559
# val_score   twostream   regression (0, 0, 1)  9.0    9        5      conc       0        97.629829
# test_score  twostream   regression (0, 0, 1)  9.0    9        5      conc       0        97.963737
#
#                                                                                           mslog_e  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 20) 9.0    3        2.5    none       0        0.737132
# val_score   flow        regression (0, 0, 20) 9.0    3        2.5    none       0        0.613319
# test_score  flow        regression (0, 0, 20) 9.0    3        2.5    none       0        0.625893
# train_score flow        regression (0, 0, 9)  81.0   3        5      avg        0        0.713384
# val_score   flow        regression (0, 0, 9)  81.0   3        5      avg        0        0.610448
# ...                                                                                           ...
#             twostream   regression (0, 0, 3)  9.0    9        5      avg        0        3.112443
# test_score  twostream   regression (0, 0, 3)  9.0    9        5      avg        0        3.242527
# train_score twostream   regression (0, 0, 1)  9.0    9        5      conc       0        3.422715
# val_score   twostream   regression (0, 0, 1)  9.0    9        5      conc       0        3.112443
# test_score  twostream   regression (0, 0, 1)  9.0    9        5      conc       0        3.242527
#
#                                                                                          CosineSimilarity  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 20) 9.0    3        2.5    none       0               -1.732055
# val_score   flow        regression (0, 0, 20) 9.0    3        2.5    none       0               -1.732054
# test_score  flow        regression (0, 0, 20) 9.0    3        2.5    none       0               -1.732054
# train_score flow        regression (0, 0, 9)  81.0   3        5      avg        0               -1.732055
# val_score   flow        regression (0, 0, 9)  81.0   3        5      avg        0               -1.732051
# ...                                                                                                   ...
#             twostream   regression (0, 0, 3)  9.0    9        5      avg        0               -3.000000
# test_score  twostream   regression (0, 0, 3)  9.0    9        5      avg        0               -3.000000
# train_score twostream   regression (0, 0, 1)  9.0    9        5      conc       0               -3.000000
# val_score   twostream   regression (0, 0, 1)  9.0    9        5      conc       0               -3.000000
# test_score  twostream   regression (0, 0, 1)  9.0    9        5      conc       0               -3.000000
#
#                                                                                             Huber  \
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 20) 9.0    3        2.5    none       0        1.302689
# val_score   flow        regression (0, 0, 20) 9.0    3        2.5    none       0        1.071499
# test_score  flow        regression (0, 0, 20) 9.0    3        2.5    none       0        1.097629
# train_score flow        regression (0, 0, 9)  81.0   3        5      avg        0        1.258240
# val_score   flow        regression (0, 0, 9)  81.0   3        5      avg        0        1.066025
# ...                                                                                           ...
#             twostream   regression (0, 0, 3)  9.0    9        5      avg        0        5.020539
# test_score  twostream   regression (0, 0, 3)  9.0    9        5      avg        0        5.184497
# train_score twostream   regression (0, 0, 1)  9.0    9        5      conc       0        5.601917
# val_score   twostream   regression (0, 0, 1)  9.0    9        5      conc       0        5.020539
# test_score  twostream   regression (0, 0, 1)  9.0    9        5      conc       0        5.184497
#
#                                                                                           LogCosh
#             featureType prblemType confID     budget eng_lvls divide fusionType repeats
# train_score flow        regression (0, 0, 20) 9.0    3        2.5    none       0        1.162706
# val_score   flow        regression (0, 0, 20) 9.0    3        2.5    none       0        0.953380
# test_score  flow        regression (0, 0, 20) 9.0    3        2.5    none       0        0.961962
# train_score flow        regression (0, 0, 9)  81.0   3        5      avg        0        1.122618
# val_score   flow        regression (0, 0, 9)  81.0   3        5      avg        0        0.948171
# ...                                                                                           ...
#             twostream   regression (0, 0, 3)  9.0    9        5      avg        0        4.829145
# test_score  twostream   regression (0, 0, 3)  9.0    9        5      avg        0        4.991432
# train_score twostream   regression (0, 0, 1)  9.0    9        5      conc       0        5.409942
# val_score   twostream   regression (0, 0, 1)  9.0    9        5      conc       0        4.829145
# test_score  twostream   regression (0, 0, 1)  9.0    9        5      conc       0        4.991432
#
# [105 rows x 7 columns]

# %% [markdown]
# ### read handcraft results
