# %% [markdown]
# # Reading & analyzing results
# now all the results of all premutions are sored as pkl
#
# we need to get the best results of all

# %% [markdown]
# ### import & vars

# %%
import sys
import numpy as np
import os
import pandas as pd
import itertools
import pickle

from collections import Counter
from sklearn.utils import shuffle
from imblearn.over_sampling import RandomOverSampler as resample

lables_path = './labels/'
features_path = './features/'
results_path = './modelling_results/'

# %% [markdown]
# ### help functions

# %% [markdown]
# ### let's analyze

# %% [markdown]
# ### step 1 -- combine in one guint cvs

# %%
# repeats = 0
# all_results = pd.DataFrame([])

# onlyfolders = [f for f in os.listdir(results_path) if not
#                        os.path.isfile(os.path.join(results_path, f))
#                        and f.count('classification') > 0]
# onlyfolders.sort()
# print(onlyfolders)
    
# for this_folder in onlyfolders:
#     print(this_folder)
#     featureType,prblemType,eng_lvls,divide,fusionType,repeats = this_folder.split('_')
#     shared_directory = os.path.join(results_path,this_folder)
    
#     results_file = os.path.join(shared_directory,'results.pkl')
#     if not os.path.exists(results_file):
#         print('ERROR: file {} does not exsist'.format(results_file))
#         continue
        
#     try:
#         res = pickle.load(open(results_file, "rb" ))
#     except:
#         continue
#     # id2config = res.get_id2config_mapping()
#     # incumbent = res.get_incumbent_id()

#     for key in res.data.keys():
#         this_data = res[key]
#         for bugKey in this_data.results.keys():
#             this_results = pd.DataFrame.from_dict(this_data.results[bugKey]['info']).T
#             this_results['budget'] = str(bugKey)
#             this_results['confID'] = str(key)
#             this_results['featureType'] = featureType
#             this_results['prblemType'] = prblemType
#             this_results['eng_lvls'] = eng_lvls
#             this_results['divide'] = divide
#             this_results['fusionType'] = fusionType
#             this_results['repeats'] = repeats
            
#             this_results.set_index(['featureType', 'prblemType', 'confID',\
#                                     'budget', 'eng_lvls', 'divide','fusionType','repeats'],\
#                                    append=True, inplace=True)
#             # cols = this_results.columns.tolist()

#             all_results = this_results if len(all_results) ==0 else all_results.append(this_results)


# print(all_results.describe())
# all_results.to_csv(os.path.join(results_path,'all_classification_results.csv'))

# %%
repeats = 0
best_results = pd.DataFrame([])

onlyfolders = [f for f in os.listdir(results_path) if not
                       os.path.isfile(os.path.join(results_path, f))
                       and f.count('handcrafted_classification') > 0]
onlyfolders.sort()
    
for this_folder in onlyfolders:
    print(this_folder)
    #featureType,prblemType,eng_lvls,divide,fusionType,repeats = this_folder.split('_')
    ss = len(this_folder.split('_'))
    if ss == 5:
        featureType,prblemType,eng_lvls,divide,repeats = this_folder.split('_')
        fusionType = 'none'
    elif ss == 6:
        featureType,prblemType,eng_lvls,divide,fusionType,repeats = this_folder.split('_')
    elif ss ==7:
        featureType,prblemType,eng_lvls,divide,fusionType1,fusionType2,repeats = this_folder.split('_')
        fusionType = '_'.join([fusionType1,fusionType2])
    elif ss ==8:
        featureType,prblemType,eng_lvls,divide,fusionType1,fusionType2,fusionType3,repeats = this_folder.split('_')
        fusionType = '_'.join([fusionType1,fusionType2,fusionType3])
    else:
        print('Cannot parse:',this_folder.split('_'))

    shared_directory = os.path.join(results_path,this_folder)
    
    results_file = os.path.join(shared_directory,'results.pkl')
    if not os.path.exists(results_file):
        print('ERROR: file {} does not exsist'.format(results_file))
        continue
        
    try:
        res = pickle.load(open(results_file, "rb" ))
    except:
        continue
    id2config = res.get_id2config_mapping()
    incumbent = res.get_incumbent_id()
    

    this_data = res[incumbent]
    new_dic = dict(zip([key for key in this_data.results.keys()],\
                       [this_data.results[k]['loss'] for k in this_data.results.keys()]))
 
    bugKey = min(new_dic, key=new_dic.get)
    
    this_results = pd.DataFrame.from_dict(this_data.results[bugKey]['info']).T
    this_results['budget'] = str(bugKey)
    this_results['confID'] = str(incumbent)
    this_results['featureType'] = featureType
    this_results['prblemType'] = prblemType
    this_results['eng_lvls'] = eng_lvls
    this_results['divide'] = divide
    this_results['fusionType'] = fusionType
    this_results['repeats'] = repeats

    this_results.set_index(['featureType', 'prblemType', 'confID',\
                            'budget', 'eng_lvls', 'divide','fusionType','repeats'],\
                           append=True, inplace=True)
    # cols = this_results.columns.tolist()

    best_results = best_results if len(this_results) ==0 else best_results.append(this_results)


print(best_results)
best_results.to_csv(os.path.join(results_path,'best_classification_results_SMOTE_normalized.csv'))
# Out:
# handcrafted_classification_2_2.5_0
# handcrafted_classification_2_2.5_ProWSyn_0
# handcrafted_classification_2_2.5_distance_SMOTE_0
# handcrafted_classification_2_2.5_polynom_fit_SMOTE_0
# handcrafted_classification_2_5_0
# handcrafted_classification_2_5_ProWSyn_0
# handcrafted_classification_2_5_distance_SMOTE_0
# handcrafted_classification_2_5_polynom_fit_SMOTE_0
# handcrafted_classification_2_5s_0
# handcrafted_classification_2_5s_ProWSyn_0
# handcrafted_classification_2_5s_distance_SMOTE_0
# handcrafted_classification_2_5s_polynom_fit_SMOTE_0
# handcrafted_classification_3_2.5_0
# handcrafted_classification_3_2.5_ProWSyn_0
# handcrafted_classification_3_2.5_distance_SMOTE_0
# handcrafted_classification_3_2.5_polynom_fit_SMOTE_0
# handcrafted_classification_3_5_0
# handcrafted_classification_3_5_ProWSyn_0
# handcrafted_classification_3_5_distance_SMOTE_0
# handcrafted_classification_3_5_polynom_fit_SMOTE_0
# handcrafted_classification_3_5s_0
# handcrafted_classification_3_5s_ProWSyn_0
# handcrafted_classification_3_5s_distance_SMOTE_0
# handcrafted_classification_3_5s_polynom_fit_SMOTE_0
# handcrafted_classification_5_2.5_0
# handcrafted_classification_5_2.5_ProWSyn_0
# handcrafted_classification_5_2.5_distance_SMOTE_0
# handcrafted_classification_5_2.5_polynom_fit_SMOTE_0
# handcrafted_classification_5_5_0
# handcrafted_classification_5_5_ProWSyn_0
# handcrafted_classification_5_5_distance_SMOTE_0
# handcrafted_classification_5_5_polynom_fit_SMOTE_0
# handcrafted_classification_5_5s_0
# handcrafted_classification_5_5s_ProWSyn_0
# handcrafted_classification_5_5s_distance_SMOTE_0
# handcrafted_classification_5_5s_polynom_fit_SMOTE_0
# handcrafted_classification_9_2.5_0
# handcrafted_classification_9_2.5_ProWSyn_0
# handcrafted_classification_9_2.5_distance_SMOTE_0
# handcrafted_classification_9_2.5_polynom_fit_SMOTE_0
# handcrafted_classification_9_5_0
# handcrafted_classification_9_5_ProWSyn_0
# handcrafted_classification_9_5_distance_SMOTE_0
# handcrafted_classification_9_5_polynom_fit_SMOTE_0
# handcrafted_classification_9_5s_0
# handcrafted_classification_9_5s_ProWSyn_0
# handcrafted_classification_9_5s_distance_SMOTE_0
# handcrafted_classification_9_5s_polynom_fit_SMOTE_0
#                                                                                                     thisloss  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.489200
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.807641
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.651554
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.266822
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.670367
# ...                                                                                                      ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        2.504992
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        1.687047
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        1.164307
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        2.320870
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        1.763456
#
#                                                                                                          tp  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        23144.0
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0         3304.0
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0         4620.0
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        26440.0
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0         4512.0
# ...                                                                                                     ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0          235.0
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0          116.0
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0         6848.0
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0            0.0
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0            5.0
#
#                                                                                                         fp  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        6660.0
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        2702.0
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        2516.0
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        3364.0
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        1494.0
# ...                                                                                                    ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0         540.0
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0         369.0
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0         435.0
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0          41.0
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0          28.0
#
#                                                                                                           tn  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0         23144.0
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0          3304.0
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0          4620.0
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0         26440.0
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0          4512.0
# ...                                                                                                      ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0         50980.0
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0         39135.0
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        237549.0
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0         53575.0
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0         41852.0
#
#                                                                                                          fn  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0         6660.0
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0         2702.0
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0         2516.0
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0         3364.0
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0         1494.0
# ...                                                                                                     ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0         6205.0
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0         4822.0
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        22900.0
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0         6702.0
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0         5230.0
#
#                                                                                                          acc  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.776540
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.550117
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.647422
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.887129
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.751249
# ...                                                                                                      ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.883627
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.883195
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.912843
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.888207
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.888399
#
#                                                                                                         prec  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.776540
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.550117
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.647422
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.887129
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.751249
# ...                                                                                                      ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.303226
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.239175
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.940272
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.000000
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.151515
#
#                                                                                                          rec  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.776540
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.550117
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.647422
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.887129
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.751249
# ...                                                                                                      ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.036491
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.023491
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.230200
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.000000
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.000955
#
#                                                                                                          auc  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.852481
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.563461
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.685273
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.957139
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.810290
# ...                                                                                                      ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.649758
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.810984
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.920636
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.653769
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.771930
#
#                                                                                                           BC  \
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.552700
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.713787
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.648753
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.377214
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.591958
# ...                                                                                                      ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.753890
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.633729
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        1.091237
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        1.165025
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        1.136185
#
#                                                                                                          MCC
#             featureType prblemType     confID     budget eng_lvls divide fusionType        repeats
# train_score handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.553433
# val_score   handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.104422
# test_score  handcrafted classification (0, 0, 10) 81.0   2        2.5    none              0        0.295782
# train_score handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.778898
# val_score   handcrafted classification (0, 0, 8)  27.0   2        2.5    ProWSyn           0        0.514699
# ...                                                                                                      ...
#                                        (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.074683
# test_score  handcrafted classification (0, 0, 19) 27.0   9        5s     distance_SMOTE    0        0.270008
# train_score handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.515456
# val_score   handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.074711
# test_score  handcrafted classification (0, 0, 15) 9.0    9        5s     polynom_fit_SMOTE 0        0.123394
#
# [144 rows x 11 columns]
